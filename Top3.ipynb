# %%
import pandas as pd
import json

with open('C:\\Users\\vinut\\Desktop\\DataMining Project\\Software_5.json') as f:
    data = [json.loads(line) for line in f]
df = pd.DataFrame(data)
df.to_csv('output.csv', index=False)

# %%
df = pd.read_csv('output.csv')
df_sorted = df.sort_values(by='asin')
asin_counts = df_sorted['asin'].value_counts()
unique = asin_counts.index.tolist()
count = asin_counts.values.tolist()
unique_asin_data = pd.DataFrame({'asin': unique, 'count': count})
print("Unique values and their counts:")
print(unique_asin_data)

sum_hundred = asin_counts.head(100).sum()
print("Sum of the first 100 counts:", sum_hundred)
# Out:
# Unique values and their counts:
#            asin  count
# 0    B0000AZJY6    452
# 1    B000EORV8Q    232
# 2    B0001FS9NE    230
# 3    B000050ZRE    230
# 4    B00EZPXYP4     98
# ..          ...    ...
# 797  B0011SFXCK      1
# 798  B00149YSUY      1
# 799  B0012KW3KM      1
# 800  B00132DENO      1
# 801  B0015CA9VW      1
#
# [802 rows x 2 columns]
# Sum of the first 100 counts: 4938

# %%
import pandas as pd

# Assuming your data is in a DataFrame named 'df'
# Replace 'your_dataset.csv' with your actual dataset filename
df = pd.read_csv('output.csv')

# Filter data for 'B0000AZJY6'
filtered_data = df[df['asin'] == 'B0001FS9NE']

# Save filtered data to a new file
filtered_data.to_csv('B0001FS9NE_data.csv', index=False)

# %%
df3 = pd.read_csv('C:\\Users\\vinut\\Desktop\\DataMining Project\\B0001FS9NE_data.csv')

df3.head(5)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  style  \
# 0      5.0      True   04 9, 2018  A2N4Y0OQ8RP88Y  B0001FS9NE    NaN
# 1      5.0      True  03 28, 2018  A24G9X47GNVI02  B0001FS9NE    NaN
# 2      5.0      True  02 22, 2018  A1JV5541KYYH9Y  B0001FS9NE    NaN
# 3      5.0      True  02 15, 2018  A3HM2ZVKF7Z8LJ  B0001FS9NE    NaN
# 4      5.0      True  02 15, 2018  A147A9US858FV8  B0001FS9NE    NaN
#
#   reviewerName                                         reviewText  \
# 0   Pat Senter  I thought this to be very inexpensive for all ...
# 1       Freddy  very good computer the intel Dual Core i3-2120...
# 2   Jim Hanson  fantastic deal. very fast. great screen. solid...
# 3   mark braun  Convertible\nSize\nHArd drive space\nLike ever...
# 4       Jayson                                       awesome fast
#
#                                              summary  unixReviewTime  vote  \
# 0  Great for the you boys for their computer cent...      1523232000   NaN
# 1   very good computer the intel Dual Core i3-2120 3      1522195200   NaN
# 2                      excellent value, high quality      1519257600   NaN
# 3                                        Convertible      1518652800   NaN
# 4                                         Five Stars      1518652800   NaN
#
#    image
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
print(df3.columns)
# Out:
# Index(['overall', 'verified', 'reviewTime', 'reviewerID', 'asin', 'style',
#        'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'vote',
#        'image'],
#       dtype='object')

# %%
columns_to_remove = ['image', 'style']
df3 = df3.drop(columns=columns_to_remove)
df3.head(5)
# Out:
#    overall  verified   reviewTime      reviewerID        asin reviewerName  \
# 0      5.0      True   04 9, 2018  A2N4Y0OQ8RP88Y  B0001FS9NE   Pat Senter
# 1      5.0      True  03 28, 2018  A24G9X47GNVI02  B0001FS9NE       Freddy
# 2      5.0      True  02 22, 2018  A1JV5541KYYH9Y  B0001FS9NE   Jim Hanson
# 3      5.0      True  02 15, 2018  A3HM2ZVKF7Z8LJ  B0001FS9NE   mark braun
# 4      5.0      True  02 15, 2018  A147A9US858FV8  B0001FS9NE       Jayson
#
#                                           reviewText  \
# 0  I thought this to be very inexpensive for all ...
# 1  very good computer the intel Dual Core i3-2120...
# 2  fantastic deal. very fast. great screen. solid...
# 3  Convertible\nSize\nHArd drive space\nLike ever...
# 4                                       awesome fast
#
#                                              summary  unixReviewTime  vote
# 0  Great for the you boys for their computer cent...      1523232000   NaN
# 1   very good computer the intel Dual Core i3-2120 3      1522195200   NaN
# 2                      excellent value, high quality      1519257600   NaN
# 3                                        Convertible      1518652800   NaN
# 4                                         Five Stars      1518652800   NaN

# %%
null = df3.isnull().sum()
print(null)
# Out:
# overall             0
# verified            0
# reviewTime          0
# reviewerID          0
# asin                0
# reviewerName        0
# reviewText          0
# summary             1
# unixReviewTime      0
# vote              230
# dtype: int64

# %%
df3['summary'].fillna('No summary', inplace=True)
df3['vote'].fillna(0, inplace=True)
null2 = df3.isnull().sum()
print(null2)
# Out:
# overall           0
# verified          0
# reviewTime        0
# reviewerID        0
# asin              0
# reviewerName      0
# reviewText        0
# summary           0
# unixReviewTime    0
# vote              0
# dtype: int64

# %%
count = df3['verified'].value_counts()
print(count)
df3
# Out:
# verified
# True     173
# False     57
# Name: count, dtype: int64
#      overall  verified   reviewTime      reviewerID        asin  \
# 0        5.0      True   04 9, 2018  A2N4Y0OQ8RP88Y  B0001FS9NE
# 1        5.0      True  03 28, 2018  A24G9X47GNVI02  B0001FS9NE
# 2        5.0      True  02 22, 2018  A1JV5541KYYH9Y  B0001FS9NE
# 3        5.0      True  02 15, 2018  A3HM2ZVKF7Z8LJ  B0001FS9NE
# 4        5.0      True  02 15, 2018  A147A9US858FV8  B0001FS9NE
# ..       ...       ...          ...             ...         ...
# 225      1.0      True  05 17, 2018  A2RV54OXBGRD2Z  B0001FS9NE
# 226      5.0     False  05 16, 2018  A3PWOYJPO4CT93  B0001FS9NE
# 227      1.0     False  05 15, 2018  A2HL609RR13WNZ  B0001FS9NE
# 228      1.0      True  05 14, 2018  A14HDK1OLFYMVM  B0001FS9NE
# 229      1.0     False  05 13, 2018  A3P2DW4YDYK88C  B0001FS9NE
#
#                reviewerName  \
# 0                Pat Senter
# 1                    Freddy
# 2                Jim Hanson
# 3                mark braun
# 4                    Jayson
# ..                      ...
# 225             minwei chen
# 226              Camille M.
# 227  George Leroy Tirebiter
# 228                      AL
# 229                W. Racca
#
#                                             reviewText  \
# 0    I thought this to be very inexpensive for all ...
# 1    very good computer the intel Dual Core i3-2120...
# 2    fantastic deal. very fast. great screen. solid...
# 3    Convertible\nSize\nHArd drive space\nLike ever...
# 4                                         awesome fast
# ..                                                 ...
# 225  The review that has 5 stars\nI really wonder t...
# 226  perfect device. the only thing that would Make...
# 227  All the reviews are not for the product listed...
# 228  So far, I am not impressed. It did arrive quic...
# 229  I looked at purchasing this Router.  However, ...
#
#                                                summary  unixReviewTime  vote
# 0    Great for the you boys for their computer cent...      1523232000   0.0
# 1     very good computer the intel Dual Core i3-2120 3      1522195200   0.0
# 2                        excellent value, high quality      1519257600   0.0
# 3                                          Convertible      1518652800   0.0
# 4                                           Five Stars      1518652800   0.0
# ..                                                 ...             ...   ...
# 225  ... doesn't stay connected the whole time I wo...      1526515200   0.0
# 226  perfect device. the only thing that would Make...      1526428800   0.0
# 227                                Doesn't Make Sense.      1526342400   0.0
# 228              Does Not Work. I Feel I've Been "Had"      1526256000   0.0
# 229  I looked at purchasing this Router. However, o...      1526169600   0.0
#
# [230 rows x 10 columns]

# %%
columns_to_remove = ['unixReviewTime', 'reviewTime','reviewerName','verified','vote']
df3 = df3.drop(columns=columns_to_remove)
df3.head(5)
# Out:
#    overall      reviewerID        asin  \
# 0      5.0  A2N4Y0OQ8RP88Y  B0001FS9NE
# 1      5.0  A24G9X47GNVI02  B0001FS9NE
# 2      5.0  A1JV5541KYYH9Y  B0001FS9NE
# 3      5.0  A3HM2ZVKF7Z8LJ  B0001FS9NE
# 4      5.0  A147A9US858FV8  B0001FS9NE
#
#                                           reviewText  \
# 0  I thought this to be very inexpensive for all ...
# 1  very good computer the intel Dual Core i3-2120...
# 2  fantastic deal. very fast. great screen. solid...
# 3  Convertible\nSize\nHArd drive space\nLike ever...
# 4                                       awesome fast
#
#                                              summary
# 0  Great for the you boys for their computer cent...
# 1   very good computer the intel Dual Core i3-2120 3
# 2                      excellent value, high quality
# 3                                        Convertible
# 4                                         Five Stars

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
def tokenize_text(text):
    tokens = word_tokenize(str(text))  # Tokenize the text
    return tokens
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vinut\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Tokenizing 'reviewText' column
df3['reviewText'] = df3['reviewText'].apply(tokenize_text)

# Tokenizing 'summary' column
df3['summary'] = df3['summary'].apply(tokenize_text)

print()

# %%
# printing reviewText 
print("Tokenized Review Text:")
for index, tokens in enumerate(df3['reviewText'].head(), start=1):
    print(f"Row {index}: {tokens}")

# Printing tokenized summary
print("\nTokenized Summary:")
for index, tokens in enumerate(df3['summary'].head(), start=1):
    print(f"Row {index}: {tokens}")
# Out:
# Tokenized Review Text:
# Row 1: ['I', 'thought', 'this', 'to', 'be', 'very', 'inexpensive', 'for', 'all', 'that', 'we', 'got', '.', 'Great', 'for', 'the', 'you', 'boys', 'for', 'their', 'computer', 'center', 'in', 'our', 'home', 'school', '.']
# Row 2: ['very', 'good', 'computer', 'the', 'intel', 'Dual', 'Core', 'i3-2120', '3.3GHz', 'CPU', ',', '4GB', 'DDR3', 'RAM', ',', '500GB', 'HDD', 'configuration', 'is', 'good', 'enough', 'for', 'light', 'use', '.', 'The', 'price', 'is', 'amazing']
# Row 3: ['fantastic', 'deal', '.', 'very', 'fast', '.', 'great', 'screen', '.', 'solid', 'laptop', '.', 'really', 'good', '.']
# Row 4: ['Convertible', 'Size', 'HArd', 'drive', 'space', 'Like', 'everything']
# Row 5: ['awesome', 'fast']
#
# Tokenized Summary:
# Row 1: ['Great', 'for', 'the', 'you', 'boys', 'for', 'their', 'computer', 'center', 'in', '...']
# Row 2: ['very', 'good', 'computer', 'the', 'intel', 'Dual', 'Core', 'i3-2120', '3']
# Row 3: ['excellent', 'value', ',', 'high', 'quality']
# Row 4: ['Convertible']
# Row 5: ['Five', 'Stars']

# %%
df3['reviewText'] = df3['reviewText'].apply(lambda tokens: [token.lower() for token in tokens])

df3['summary'] = df3['summary'].apply(lambda tokens: [token.lower() for token in tokens])

# %%
print("Lowercase Tokens for Review Text:")
for index, tokens in enumerate(df3['reviewText'].head(), start=1):
    print(f"Row {index}: {tokens}")

print("\nLowercase Tokens for Summary:")
for index, tokens in enumerate(df3['summary'].head(), start=1):
    print(f"Row {index}: {tokens}")
# Out:
# Lowercase Tokens for Review Text:
# Row 1: ['i', 'thought', 'this', 'to', 'be', 'very', 'inexpensive', 'for', 'all', 'that', 'we', 'got', '.', 'great', 'for', 'the', 'you', 'boys', 'for', 'their', 'computer', 'center', 'in', 'our', 'home', 'school', '.']
# Row 2: ['very', 'good', 'computer', 'the', 'intel', 'dual', 'core', 'i3-2120', '3.3ghz', 'cpu', ',', '4gb', 'ddr3', 'ram', ',', '500gb', 'hdd', 'configuration', 'is', 'good', 'enough', 'for', 'light', 'use', '.', 'the', 'price', 'is', 'amazing']
# Row 3: ['fantastic', 'deal', '.', 'very', 'fast', '.', 'great', 'screen', '.', 'solid', 'laptop', '.', 'really', 'good', '.']
# Row 4: ['convertible', 'size', 'hard', 'drive', 'space', 'like', 'everything']
# Row 5: ['awesome', 'fast']
#
# Lowercase Tokens for Summary:
# Row 1: ['great', 'for', 'the', 'you', 'boys', 'for', 'their', 'computer', 'center', 'in', '...']
# Row 2: ['very', 'good', 'computer', 'the', 'intel', 'dual', 'core', 'i3-2120', '3']
# Row 3: ['excellent', 'value', ',', 'high', 'quality']
# Row 4: ['convertible']
# Row 5: ['five', 'stars']

# %%
import re

# Function to remove special characters and spaces from tokens
def remove_special_characters(tokens):
    # Define regex pattern to remove spaces and special characters
    pattern = r'[^a-zA-Z0-9]'  # Keeps letters and numbers
    
    # Remove special characters and spaces using regex
    tokens_no_special = [re.sub(pattern, '', token) for token in tokens]
    tokens_no_special = [token for token in tokens_no_special if token]  # Remove empty strings
    return tokens_no_special

# Remove special characters and spaces from 'reviewText' column
df3['reviewText'] = df3['reviewText'].apply(remove_special_characters)

# Remove special characters and spaces from 'summary' column
df3['summary'] = df3['summary'].apply(remove_special_characters)

# %%
# Print tokens with special characters removed for 'reviewText_tokens_clean' column
print("Tokens with Special Characters Removed for Review Text:")
for index, tokens in enumerate(df3['reviewText'].head(), start=1):
    print(f"Row {index}: {tokens}")

# Print tokens with special characters removed for 'summary_tokens_clean' column
print("\nTokens with Special Characters Removed for Summary:")
for index, tokens in enumerate(df3['summary'].head(), start=1):
    print(f"Row {index}: {tokens}")
# Out:
# Tokens with Special Characters Removed for Review Text:
# Row 1: ['i', 'thought', 'this', 'to', 'be', 'very', 'inexpensive', 'for', 'all', 'that', 'we', 'got', 'great', 'for', 'the', 'you', 'boys', 'for', 'their', 'computer', 'center', 'in', 'our', 'home', 'school']
# Row 2: ['very', 'good', 'computer', 'the', 'intel', 'dual', 'core', 'i32120', '33ghz', 'cpu', '4gb', 'ddr3', 'ram', '500gb', 'hdd', 'configuration', 'is', 'good', 'enough', 'for', 'light', 'use', 'the', 'price', 'is', 'amazing']
# Row 3: ['fantastic', 'deal', 'very', 'fast', 'great', 'screen', 'solid', 'laptop', 'really', 'good']
# Row 4: ['convertible', 'size', 'hard', 'drive', 'space', 'like', 'everything']
# Row 5: ['awesome', 'fast']
#
# Tokens with Special Characters Removed for Summary:
# Row 1: ['great', 'for', 'the', 'you', 'boys', 'for', 'their', 'computer', 'center', 'in']
# Row 2: ['very', 'good', 'computer', 'the', 'intel', 'dual', 'core', 'i32120', '3']
# Row 3: ['excellent', 'value', 'high', 'quality']
# Row 4: ['convertible']
# Row 5: ['five', 'stars']

# %%
import nltk
from nltk.corpus import stopwords

# Download NLTK stopwords if not downloaded
nltk.download('stopwords')

# Get English stopwords from NLTK
stop_words = set(stopwords.words('english'))

# Function to remove stopwords from tokens
def remove_stopwords(tokens):
    tokens_no_stop = [token for token in tokens if token not in stop_words]
    return tokens_no_stop

# Remove stopwords from 'reviewText_tokens_no_punct' column
df3['reviewText'] = df3['reviewText'].apply(remove_stopwords)

# Remove stopwords from 'summary_tokens_no_punct' column
df3['summary'] = df3['summary'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vinut\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Print tokens without stopwords for 'reviewText_tokens_no_stop' column
print("Tokens without Stopwords for Review Text:")
for index, tokens in enumerate(df3['reviewText'].head(), start=1):
    print(f"Row {index}: {tokens}")

# Print tokens without stopwords for 'summary_tokens_no_stop' column
print("\nTokens without Stopwords for Summary:")
for index, tokens in enumerate(df3['summary'].head(), start=1):
    print(f"Row {index}: {tokens}")
# Out:
# Tokens without Stopwords for Review Text:
# Row 1: ['thought', 'inexpensive', 'got', 'great', 'boys', 'computer', 'center', 'home', 'school']
# Row 2: ['good', 'computer', 'intel', 'dual', 'core', 'i32120', '33ghz', 'cpu', '4gb', 'ddr3', 'ram', '500gb', 'hdd', 'configuration', 'good', 'enough', 'light', 'use', 'price', 'amazing']
# Row 3: ['fantastic', 'deal', 'fast', 'great', 'screen', 'solid', 'laptop', 'really', 'good']
# Row 4: ['convertible', 'size', 'hard', 'drive', 'space', 'like', 'everything']
# Row 5: ['awesome', 'fast']
#
# Tokens without Stopwords for Summary:
# Row 1: ['great', 'boys', 'computer', 'center']
# Row 2: ['good', 'computer', 'intel', 'dual', 'core', 'i32120', '3']
# Row 3: ['excellent', 'value', 'high', 'quality']
# Row 4: ['convertible']
# Row 5: ['five', 'stars']

# %%
df3
# Out:
#      overall      reviewerID        asin  \
# 0        5.0  A2N4Y0OQ8RP88Y  B0001FS9NE
# 1        5.0  A24G9X47GNVI02  B0001FS9NE
# 2        5.0  A1JV5541KYYH9Y  B0001FS9NE
# 3        5.0  A3HM2ZVKF7Z8LJ  B0001FS9NE
# 4        5.0  A147A9US858FV8  B0001FS9NE
# ..       ...             ...         ...
# 225      1.0  A2RV54OXBGRD2Z  B0001FS9NE
# 226      5.0  A3PWOYJPO4CT93  B0001FS9NE
# 227      1.0  A2HL609RR13WNZ  B0001FS9NE
# 228      1.0  A14HDK1OLFYMVM  B0001FS9NE
# 229      1.0  A3P2DW4YDYK88C  B0001FS9NE
#
#                                             reviewText  \
# 0    [thought, inexpensive, got, great, boys, compu...
# 1    [good, computer, intel, dual, core, i32120, 33...
# 2    [fantastic, deal, fast, great, screen, solid, ...
# 3    [convertible, size, hard, drive, space, like, ...
# 4                                      [awesome, fast]
# ..                                                 ...
# 225  [review, 5, stars, really, wonder, real, nt, s...
# 226  [perfect, device, thing, would, make, better, ...
# 227  [reviews, product, listed, amazon, needs, stra...
# 228  [far, impressed, arrive, quickly, work, us, fo...
# 229  [looked, purchasing, router, however, one, won...
#
#                                                summary
# 0                      [great, boys, computer, center]
# 1       [good, computer, intel, dual, core, i32120, 3]
# 2                    [excellent, value, high, quality]
# 3                                        [convertible]
# 4                                        [five, stars]
# ..                                                 ...
# 225  [nt, stay, connected, whole, time, would, reco...
# 226              [perfect, device, thing, would, make]
# 227                                  [nt, make, sense]
# 228                                       [work, feel]
# 229         [looked, purchasing, router, however, one]
#
# [230 rows x 5 columns]

# %%
# Function to get sentiment polarity
from textblob import TextBlob
def get_sentiment(text):
    analysis = TextBlob(str(text))
    return analysis.sentiment.polarity
df3['sentiment'] = df3['reviewText'].apply(get_sentiment)
print(df3[['reviewText', 'sentiment']].head(10))
# Out:
#                                           reviewText  sentiment
# 0  [thought, inexpensive, got, great, boys, compu...   0.350000
# 1  [good, computer, intel, dual, core, i32120, 33...   0.480000
# 2  [fantastic, deal, fast, great, screen, solid, ...   0.420000
# 3  [convertible, size, hard, drive, space, like, ...  -0.291667
# 4                                    [awesome, fast]   0.600000
# 5  [covers, screen, barely, sides, falls, bit, sh...   0.286429
# 6                                           [thanks]   0.200000
# 7  [using, month, fast, starts, quickly, screen, ...   0.177778
# 8  [delivered, time, product, exactly, described,...   0.250000
# 9                                        [estupendo]   0.000000

# %%
# Function to convert sentiment scores to categorical values
def get_sentiment_category(score):
    if score >= 0.3:  
        return 1  # Positive sentiment
    elif score < -0.1:
        return -1  # Negative sentiment
    else:
        return 0  # Neutral sentiment or no strong sentiment
df3['sentiment_category'] = df3['sentiment'].apply(get_sentiment_category)
df3.head(50)
# Out:
#     overall      reviewerID        asin  \
# 0       5.0  A2N4Y0OQ8RP88Y  B0001FS9NE
# 1       5.0  A24G9X47GNVI02  B0001FS9NE
# 2       5.0  A1JV5541KYYH9Y  B0001FS9NE
# 3       5.0  A3HM2ZVKF7Z8LJ  B0001FS9NE
# 4       5.0  A147A9US858FV8  B0001FS9NE
# 5       5.0  A1HJTB0MIC4KQN  B0001FS9NE
# 6       5.0   A7NGASCWV27S7  B0001FS9NE
# 7       5.0  A1V68ZGRMUT7YC  B0001FS9NE
# 8       5.0   AOEYPSPIR3HBL  B0001FS9NE
# 9       5.0  A3AKH3YQJ0POOA  B0001FS9NE
# 10      5.0  A3OZW1RD3LLRK8  B0001FS9NE
# 11      5.0  A24KVXQCVQ4XE8  B0001FS9NE
# 12      5.0  A18S5P9VX4QL18  B0001FS9NE
# 13      5.0  A366GHYFWYLVCI  B0001FS9NE
# 14      5.0   ACP6W0CULQ26N  B0001FS9NE
# 15      5.0   AIT20JDK6ZWZN  B0001FS9NE
# 16      5.0  A1LNWNTJV8OXKC  B0001FS9NE
# 17      5.0  A2RM0Q8VFSH0OW  B0001FS9NE
# 18      5.0  A2QU1RTXCWNAVA  B0001FS9NE
# 19      5.0  A2GG6IJ55UX6YZ  B0001FS9NE
# 20      5.0  A32OJFTLJUUPZI  B0001FS9NE
# 21      5.0   ALXRKQ572JVN4  B0001FS9NE
# 22      5.0   AK3K19MB191ZO  B0001FS9NE
# 23      5.0  A28ZB85V5UMY22  B0001FS9NE
# 24      5.0  A1TZ9MCWA6EHJ1  B0001FS9NE
# 25      5.0  A3V1DM71RMGBFB  B0001FS9NE
# 26      5.0  A1SLOSK3LFHWM1  B0001FS9NE
# 27      5.0  A3D44572MFVIMI  B0001FS9NE
# 28      5.0  A3K082UB8PHLO5  B0001FS9NE
# 29      5.0  A1I7HLVM8OHMCF  B0001FS9NE
# 30      5.0  A20PKGHQ0KQPXH  B0001FS9NE
# 31      5.0  A1YZDWOWFXC094  B0001FS9NE
# 32      5.0   A4EJM72NKO4YM  B0001FS9NE
# 33      5.0  A1JZFGZEZVWQPY  B0001FS9NE
# 34      5.0  A1OJ9V614SM587  B0001FS9NE
# 35      5.0  A2ETPOKJOA57W6  B0001FS9NE
# 36      5.0  A1JZFGZEZVWQPY  B0001FS9NE
# 37      5.0   AI6YOSOWFYF82  B0001FS9NE
# 38      5.0  A31N0XY2UTB25C  B0001FS9NE
# 39      5.0  A3RK4C2I5SPZNO  B0001FS9NE
# 40      5.0  A1E3P6P5I9H215  B0001FS9NE
# 41      5.0  A1OP3DBLTQC5SR  B0001FS9NE
# 42      5.0  A1JZFGZEZVWQPY  B0001FS9NE
# 43      5.0  A3VNNC6YER083I  B0001FS9NE
# 44      5.0  A1CTO812YAY1QP  B0001FS9NE
# 45      5.0  A1U5KM2Y6T5II0  B0001FS9NE
# 46      5.0  A2U276LA0HC7HD  B0001FS9NE
# 47      5.0  A3O3D9EFNNZ3EY  B0001FS9NE
# 48      5.0  A28QQLZKCH4IU3  B0001FS9NE
# 49      5.0  A1TL5X32Z3KNVC  B0001FS9NE
#
#                                            reviewText  \
# 0   [thought, inexpensive, got, great, boys, compu...
# 1   [good, computer, intel, dual, core, i32120, 33...
# 2   [fantastic, deal, fast, great, screen, solid, ...
# 3   [convertible, size, hard, drive, space, like, ...
# 4                                     [awesome, fast]
# 5   [covers, screen, barely, sides, falls, bit, sh...
# 6                                            [thanks]
# 7   [using, month, fast, starts, quickly, screen, ...
# 8   [delivered, time, product, exactly, described,...
# 9                                         [estupendo]
# 10  [took, whole, get, works, well, seems, well, c...
# 11                                [great, value, wap]
# 12                          [grandson, happy, laptop]
# 13               [great, find, seller, stellar, need]
# 14                                            [great]
# 15  [unit, came, used, fine, condition, seems, wor...
# 16                                        [excellent]
# 17  [great, price, company, also, provides, massiv...
# 18                  [years, works, great, power, sag]
# 19                            [ap, rocks, miss, 3com]
# 20                                 [love, good, deal]
# 21     [shelved, item, found, significant, rf, noise]
# 22  [worked, us, reliably, complaint, functioning,...
# 23                                [good, four, years]
# 24       [bought, son, mac, works, great, hp, laptop]
# 25                              [nice, simple, works]
# 26                             [omg, router, amazing]
# 27                                  [works, expected]
# 28  [ok, deal, got, 2, 1, i5core, 6gb, 1tb, hard, ...
# 29  [nice, price, like, one, phone, company, wante...
# 30                      [work, perfectly, hackintosh]
# 31             [works, nicely, 10, year, old, laptop]
# 32                                        [excellent]
# 33  [qnap, get, lot, money, inexpensive, plex, sup...
# 34                                    [worked, great]
# 35  [give, 5, star, increase, range, significantly...
# 36  [super, home, business, networks, addition, ei...
# 37                                        [excellent]
# 38  [netgear, prosafe, 8port, gigabit, click, swit...
# 39  [item, came, quickly, exactly, described, grea...
# 40  [perfect, needs, used, cable, extend, amp, ant...
# 41                                            [great]
# 42  [unit, much, faster, powerful, trendnets, acce...
# 43                       [excellent, seller, product]
# 44                                   [everything, ok]
# 45                                        [excelente]
# 46                                     [works, great]
# 47                      [working, great, good, price]
# 48                                            [works]
# 49                               [excellent, product]
#
#                                               summary  sentiment  \
# 0                     [great, boys, computer, center]   0.350000
# 1      [good, computer, intel, dual, core, i32120, 3]   0.480000
# 2                   [excellent, value, high, quality]   0.420000
# 3                                       [convertible]  -0.291667
# 4                                       [five, stars]   0.600000
# 5                        [may, look, like, protector]   0.286429
# 6                                       [five, stars]   0.200000
# 7                                      [using, month]   0.177778
# 8                                       [five, stars]   0.250000
# 9                                       [five, stars]   0.000000
# 10                    [took, whole, get, works, well]   0.200000
# 11                                      [five, stars]   0.800000
# 12                                      [five, stars]   0.800000
# 13                     [great, find, seller, stellar]   0.525000
# 14                                      [five, stars]   0.800000
# 15            [fine, condition, seems, working, well]   0.408333
# 16                                        [excellent]   1.000000
# 17                                      [five, stars]   0.400000
# 18                                             [love]   0.800000
# 19                                       [miss, 3com]   0.000000
# 20                                      [five, stars]   0.600000
# 21                 [product, works, needs, shielding]   0.375000
# 22  [switch, offers, lightweight, reduced, dimensi...   0.077778
# 23                                      [five, stars]   0.700000
# 24                                      [five, stars]   0.800000
# 25                                      [five, stars]   0.300000
# 26                                          [amazing]   0.600000
# 27                                      [five, stars]  -0.100000
# 28                                    [ok, deal, got]  -0.084817
# 29                                      [five, stars]   0.508333
# 30                                      [five, stars]   1.000000
# 31                                      [works, good]   0.350000
# 32                                        [excellent]   1.000000
# 33                                     [ts, 251, nas]  -0.114405
# 34                                        [nice, buy]   0.800000
# 35                          [give, 5, star, increase]   0.150000
# 36                  [super, home, business, networks]   0.314815
# 37                                      [five, stars]   1.000000
# 38  [outstanding, design, feature, rich, easily, m...   0.238675
# 39               [great, price, way, cheaper, seller]   0.339583
# 40                             [great, jumper, cable]   1.000000
# 41                                      [five, stars]   0.800000
# 42                                 [pleased, results]   0.033444
# 43                               [excellent, product]   1.000000
# 44                                      [five, stars]   0.500000
# 45                                      [five, stars]   0.000000
# 46                                      [five, stars]   0.800000
# 47                                      [five, stars]   0.750000
# 48                                            [works]   0.000000
# 49                                      [five, stars]   1.000000
#
#     sentiment_category
# 0                    1
# 1                    1
# 2                    1
# 3                   -1
# 4                    1
# 5                    0
# 6                    0
# 7                    0
# 8                    0
# 9                    0
# 10                   0
# 11                   1
# 12                   1
# 13                   1
# 14                   1
# 15                   1
# 16                   1
# 17                   1
# 18                   1
# 19                   0
# 20                   1
# 21                   1
# 22                   0
# 23                   1
# 24                   1
# 25                   1
# 26                   1
# 27                   0
# 28                   0
# 29                   1
# 30                   1
# 31                   1
# 32                   1
# 33                  -1
# 34                   1
# 35                   0
# 36                   1
# 37                   1
# 38                   0
# 39                   1
# 40                   1
# 41                   1
# 42                   0
# 43                   1
# 44                   1
# 45                   0
# 46                   1
# 47                   1
# 48                   0
# 49                   1

# %%
df3['sentiment_category'].value_counts()
# Out:
# sentiment_category
#  0    113
#  1    108
# -1      9
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
sentiment_categories = [114, 108, 10]
categories = ['Positive', 'Neutral', 'Negative']

#bar plot
plt.figure(figsize=(8, 6))
plt.bar(categories, sentiment_categories, color=['green', 'blue', 'red'])
plt.xlabel('Sentiment Category')
plt.ylabel('Frequency')
plt.title('Distribution of Sentiment Categories')
plt.show()

# %%
from nltk import pos_tag, word_tokenize
from collections import Counter
from wordcloud import WordCloud

positive_reviews = df3[df3['sentiment_category'] == 1]['reviewText']
feature_words = [word for review in positive_reviews for word in review]
feature_word_freq = Counter(feature_words)
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(feature_word_freq)
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Frequent Features in Positive Reviews')
plt.show()

top_features = feature_word_freq.most_common(10)  # Top 10 features
feature_names, frequencies = zip(*top_features)

plt.figure(figsize=(10, 6))
plt.barh(feature_names, frequencies, color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('Feature')
plt.title('Top Features in Positive Reviews')
plt.gca().invert_yaxis()
plt.show()

# %%
def get_sentiment(text):
    analysis = TextBlob(str(text))
    return analysis.sentiment.polarity
df3['sentiment2'] = df3['summary'].apply(get_sentiment)
print(df3[['summary', 'sentiment2']].head(10))
# Out:
#                                           summary  sentiment2
# 0                 [great, boys, computer, center]        0.35
# 1  [good, computer, intel, dual, core, i32120, 3]        0.70
# 2               [excellent, value, high, quality]        0.58
# 3                                   [convertible]        0.00
# 4                                   [five, stars]        0.00
# 5                    [may, look, like, protector]        0.00
# 6                                   [five, stars]        0.00
# 7                                  [using, month]        0.00
# 8                                   [five, stars]        0.00
# 9                                   [five, stars]        0.00

# %%
def get_sentiment_category(score):
    if score > 0.5: 
        return 1  # Positive sentiment
    elif score < -0.1:
        return -1  # Negative sentiment
    else:
        return 0  # Neutral sentiment or no strong sentiment

df3['sentiment2_category'] = df3['sentiment2'].apply(get_sentiment_category)
print(df3[['summary', 'sentiment2_category']].head(10))
# Out:
#                                           summary  sentiment2_category
# 0                 [great, boys, computer, center]                    0
# 1  [good, computer, intel, dual, core, i32120, 3]                    1
# 2               [excellent, value, high, quality]                    1
# 3                                   [convertible]                    0
# 4                                   [five, stars]                    0
# 5                    [may, look, like, protector]                    0
# 6                                   [five, stars]                    0
# 7                                  [using, month]                    0
# 8                                   [five, stars]                    0
# 9                                   [five, stars]                    0

# %%
from nltk import pos_tag, word_tokenize
from collections import Counter
from wordcloud import WordCloud
positive_reviews = df3[df3['sentiment2_category'] == 1]['summary']
feature_words = [word for review in positive_reviews for word in review]
feature_word_freq = Counter(feature_words)
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(feature_word_freq)
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Frequent Features in Positive Reviews')
plt.show()

top_features = feature_word_freq.most_common(10)  # Top 10 features
feature_names, frequencies = zip(*top_features)

plt.figure(figsize=(10, 6))
plt.barh(feature_names, frequencies, color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('Feature')
plt.title('Top Features in Positive Reviews')
plt.gca().invert_yaxis()
plt.show()

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\vinut\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#Aspect based sentiment analysis
from nltk import pos_tag
tagged_feature = pos_tag(feature_words)
aspect_keyword = [word for word, pos in tagged_feature if pos in ['NN', 'NNS', 'JJ']]
print(aspect_keyword)
# Out:
# ['good', 'computer', 'dual', 'core', 'i32120', 'excellent', 'value', 'high', 'quality', 'great', 'seller', 'stellar', 'excellent', 'amazing', 'works', 'good', 'excellent', 'nice', 'buy', 'great', 'price', 'way', 'seller', 'great', 'jumper', 'cable', 'excellent', 'product', 'dial', 'modem', 'upgrade', 'works', 'great', 'good', 'deal', 'great', 'fits', 'lowprofile', 'pc', 'good', 'item', 'good', 'deal', 'flawless', 'easy', 'setup', 'perfect', 'performance', 'switch', 'good', 'product', 'great', 'price', 'great', 'gadget', 'wifi', 'avoid', 'wifi', 'case', 'good', 'investment', 'nice', 'outstanding', 'wireless', 'good', 'price', 'perfect', 'worked', 'great', 'right', 'box', 'perfect', 'great', 'results', 'great', 'excellent', 'good', 'product', 'excellent', 'value', 'great', 'upgrade', 'great', 'array', 'price', 'easy', 'plug', 'great', 'performace', 'great', 'great', 'product', 'great', 'amazing', 'product', 'great', 'product', 'perfect', 'perfect', 'combination', 'qnap', 'nas', 'good', 'product', 'great', 'item', 'great', 'price', 'great', 'product', 'right', 'great', 'good', 'home', 'network', 'high', 'gain', 'great', 'router', 'great', 'security', 'solution', 'robotics', 'port', 'gigabit', 'excellent', 'engenius', 'products', 'great', 'switch', 'ports', 'great', 'product', 'amazing', 'machine', 'price', 'great', 'fantastic', 'price', 'great', 'product', 'modem', 'works', 'switch', 'excellent', 'device', 'usb', 'hub', 'great', 'switch', 'great', 'features', 'low', 'cost', 'speed', 'works', 'great', 'great', 'modem', 'great', 'home', 'switch', 'vlan', 'support', 'come', 'great', 'product', 'great', 'excellent', 'switch', 'excellent', 'combo', 'card', 'great', 'excellent', 'helpful', 'great', 'router', 'good', 'product', 'good', 'price', 'great', 'usb', 'card', 'good', 'product', 'easy', 'setup', 'use', 'perfect', 'device', 'thing']

# %%
df_aspect = pd.read_csv('C:\\Users\\vinut\\Desktop\\DataMining Project\\B0001FS9NE_data.csv')

df_aspect.head(5)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  style  \
# 0      5.0      True   04 9, 2018  A2N4Y0OQ8RP88Y  B0001FS9NE    NaN
# 1      5.0      True  03 28, 2018  A24G9X47GNVI02  B0001FS9NE    NaN
# 2      5.0      True  02 22, 2018  A1JV5541KYYH9Y  B0001FS9NE    NaN
# 3      5.0      True  02 15, 2018  A3HM2ZVKF7Z8LJ  B0001FS9NE    NaN
# 4      5.0      True  02 15, 2018  A147A9US858FV8  B0001FS9NE    NaN
#
#   reviewerName                                         reviewText  \
# 0   Pat Senter  I thought this to be very inexpensive for all ...
# 1       Freddy  very good computer the intel Dual Core i3-2120...
# 2   Jim Hanson  fantastic deal. very fast. great screen. solid...
# 3   mark braun  Convertible\nSize\nHArd drive space\nLike ever...
# 4       Jayson                                       awesome fast
#
#                                              summary  unixReviewTime  vote  \
# 0  Great for the you boys for their computer cent...      1523232000   NaN
# 1   very good computer the intel Dual Core i3-2120 3      1522195200   NaN
# 2                      excellent value, high quality      1519257600   NaN
# 3                                        Convertible      1518652800   NaN
# 4                                         Five Stars      1518652800   NaN
#
#    image
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
def extract_aspects(text):
    doc = nlp(text)
    aspects = []
    for token in doc:
        if token.pos_ == "NOUN":    #extracts noun
            aspects.append(token.text)
    return aspects


review_text = "All the reviews are not for the product listed. Amazon needs to straighten this mess out"
aspects = extract_aspects(review_text)
print("Aspects:",aspects)
# Out:
# Aspects: ['reviews', 'product', 'mess']

# %%
df_review = df_aspect['reviewText']

def extract_aspects(text):
    doc = nlp(text)
    aspects = [token.text for token in doc if token.pos_ == "NOUN"]
    return aspects

# applying the extract_aspects function to the 'reviewText' column
df_aspects = df_review.apply(extract_aspects)
df_review = pd.DataFrame(df_review)
df_review['aspects'] = df_aspects
df_review = df_review.rename(columns={'reviewText': 'reviews'})
print(df_review)
# Out:
#                                                reviews  \
# 0    I thought this to be very inexpensive for all ...
# 1    very good computer the intel Dual Core i3-2120...
# 2    fantastic deal. very fast. great screen. solid...
# 3    Convertible\nSize\nHArd drive space\nLike ever...
# 4                                         awesome fast
# ..                                                 ...
# 225  The review that has 5 stars\nI really wonder t...
# 226  perfect device. the only thing that would Make...
# 227  All the reviews are not for the product listed...
# 228  So far, I am not impressed. It did arrive quic...
# 229  I looked at purchasing this Router.  However, ...
#
#                                                aspects
# 0               [boys, computer, center, home, school]
# 1       [computer, i3, HDD, configuration, use, price]
# 2                               [deal, screen, laptop]
# 3                                       [drive, space]
# 4                                                   []
# ..                                                 ...
# 225                     [review, stars, time, product]
# 226                            [device, thing, people]
# 227                           [reviews, product, mess]
# 228  [instructions, times, devices, product, review...
# 229  [Router, ratings, reviews, questions, folks, p...
#
# [230 rows x 2 columns]

# %%
from collections import Counter
all_aspects = [aspect for sublist in df_review['aspects'] for aspect in sublist]
aspect_counts = Counter(all_aspects)
top_aspects = aspect_counts.most_common(5)

# Print the top aspects and their counts
print("Top Aspects:")
for aspect, count in top_aspects:
    print(f"{aspect}: {count} mentions")
# Out:
# Top Aspects:
# product: 65 mentions
# port: 65 mentions
# switch: 56 mentions
# router: 53 mentions
# power: 47 mentions

# %%
aspects, counts = zip(*top_aspects)

# Plotting the graph
plt.figure(figsize=(10, 6))
plt.bar(aspects, counts, color='skyblue')
plt.xlabel('Aspects')
plt.ylabel('Frequency')
plt.title('Top Aspects or Features')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
aspects, counts = zip(*top_aspects)

#pie chart
plt.figure(figsize=(8, 8))
plt.pie(counts, labels=aspects, autopct='%1.1f%%', startangle=140)
plt.title('Top Aspects Distribution')
plt.axis('equal')  
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings("ignore")

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_review['reviews'], df3['sentiment_category'], test_size=0.2, random_state=42)
model = make_pipeline(TfidfVectorizer(), SVC(kernel='linear', random_state=42))
#model = make_pipeline(TfidfVectorizer(), RandomForestClassifier(n_estimators=100, random_state=42))
model.fit(X_train, y_train)   #Fit the model
predictions = model.predict(X_test) # Make predictions on the test set

#find accuracy
accuracy = accuracy_score(y_test, predictions)
print("Test Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, predictions))

# For new reviews,predict:
new_reviews = [
    "Very disappointed with the performance. Would not recommend.",
    "Amazing product",
    "disappointed",
]
new_predictions = model.predict(new_reviews)
print("\nPredicted Sentiments for New Reviews:", new_predictions)
# Out:
# Test Accuracy: 0.6304347826086957
#
# Classification Report:
#                precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         4
#            0       0.70      0.73      0.72        26
#            1       0.53      0.62      0.57        16
#
#     accuracy                           0.63        46
#    macro avg       0.41      0.45      0.43        46
# weighted avg       0.58      0.63      0.60        46
#
#
# Predicted Sentiments for New Reviews: [0 1 0]

# %%
sentiment_mapping = {
    0: 'Negative',
    1: 'Positive'
}
predicted_sentiments = [sentiment_mapping[label] for label in new_predictions]
colors = ['red' if pred == 'Negative' else 'green' for pred in predicted_sentiments]

# Plotting sentiment predictions for new reviews
plt.figure(figsize=(10, 6))
plt.barh(range(len(new_reviews)), [1 if pred == 'Positive' else -1 for pred in predicted_sentiments], color=colors)
plt.yticks(range(len(new_reviews)), new_reviews)
plt.xlabel('Sentiment')
plt.title('Sentiment Predictions for New Reviews')
plt.gca().invert_yaxis()  # Invert y-axis to display the most recent review at the top
plt.show()

# %%
# top aspects and associated sentiment words with their synonyms
aspect_sentiments = {
    'product': ['excellent', 'good', 'great', 'bad', 'poor', 'disappointing'],
    'router': ['fast', 'reliable', 'slow', 'unreliable'],
    'switch': ['efficient', 'effective', 'inefficient', 'ineffective'],
    'port': ['compatible', 'incompatible', 'functional', 'non-functional'],
    'device': ['sophisticated', 'basic', 'advanced', 'outdated']
}

# rule-based sentiment analysis approach:
def rule_based_sentiment_analysis(review):
    sentiment_scores = {}
    for aspect, sentiment_words in aspect_sentiments.items():
        aspect_sentiment = 'neutral'
        for word in sentiment_words:
            if isinstance(review, str) and isinstance(word, str) and word in review.lower():
                aspect_sentiment = 'positive'
                break
        sentiment_scores[aspect] = aspect_sentiment
    
    return sentiment_scores
top_aspects = ['product', 'port', 'switch', 'router', 'power']
for aspect in top_aspects:
    reviews_with_aspect = df_review[df_review['aspects'].apply(lambda x: aspect in x)]['reviews']
    aspect_sentiments = reviews_with_aspect.apply(rule_based_sentiment_analysis)
    for idx, sentiments in aspect_sentiments.items():
        print(f"Review: {idx}")
        print("Sentiments:", sentiments)
    print()
# Out:
# Review: 8
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 38
# Sentiments: {'product': 'positive', 'router': 'positive', 'switch': 'neutral', 'port': 'neutral', 'device': 'positive'}
# Review: 49
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 51
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 54
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 60
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 62
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'positive'}
# Review: 64
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 66
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 71
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 73
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 87
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 90
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 92
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 96
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'positive', 'device': 'neutral'}
# Review: 98
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 109
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 111
# Sentiments: {'product': 'neutral', 'router': 'positive', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 113
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 120
# Sentiments: {'product': 'positive', 'router': 'positive', 'switch': 'positive', 'port': 'neutral', 'device': 'neutral'}
# Review: 121
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 123
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 124
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 127
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 133
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 142
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'positive'}
# Review: 144
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 145
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 151
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'positive'}
# Review: 157
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 160
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 179
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 182
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 186
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 190
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 193
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 199
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 202
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'positive', 'device': 'neutral'}
# Review: 204
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 222
# Sentiments: {'product': 'neutral', 'router': 'positive', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 223
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 225
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 227
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 228
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 229
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
#
# Review: 33
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 36
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 38
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 61
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 72
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 88
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 101
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 102
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 106
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 113
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 116
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 136
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 138
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 145
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 146
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 156
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 159
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 162
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 165
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 170
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 171
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 172
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 196
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 211
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 213
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 216
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 217
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 218
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
# Review: 219
# Sentiments: {8: 'positive', 38: 'positive', 49: 'positive', 51: 'positive', 54: 'positive', 60: 'positive', 62: 'positive', 64: 'positive', 66: 'positive', 71: 'positive', 73: 'positive', 87: 'positive', 90: 'positive', 92: 'positive', 96: 'positive', 98: 'positive', 109: 'positive', 111: 'positive', 113: 'positive', 120: 'positive', 121: 'positive', 123: 'positive', 124: 'positive', 127: 'positive', 133: 'positive', 142: 'positive', 144: 'positive', 145: 'positive', 151: 'positive', 157: 'positive', 160: 'positive', 179: 'positive', 182: 'positive', 186: 'positive', 190: 'positive', 193: 'positive', 199: 'positive', 202: 'positive', 204: 'positive', 222: 'positive', 223: 'positive', 225: 'positive', 227: 'positive', 228: 'positive', 229: 'positive'}
#
# Review: 22
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 36
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 38
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 39
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 64
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 65
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 72
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 103
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 104
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 110
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 113
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 146
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 154
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 156
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 163
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 165
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 168
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 170
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 175
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 178
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 184
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 186
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 193
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 216
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 218
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
# Review: 223
# Sentiments: {33: 'neutral', 36: 'neutral', 38: 'neutral', 61: 'neutral', 72: 'neutral', 88: 'neutral', 101: 'neutral', 102: 'neutral', 106: 'neutral', 113: 'neutral', 116: 'neutral', 136: 'neutral', 138: 'neutral', 145: 'neutral', 146: 'neutral', 156: 'neutral', 159: 'neutral', 162: 'neutral', 165: 'neutral', 170: 'neutral', 171: 'neutral', 172: 'neutral', 196: 'neutral', 211: 'neutral', 213: 'neutral', 216: 'neutral', 217: 'neutral', 218: 'neutral', 219: 'neutral'}
#
# Review: 26
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 35
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 83
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 112
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 116
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 117
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 127
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 128
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 132
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 135
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 140
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 143
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 145
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 159
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 160
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 164
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 173
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 196
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 201
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 203
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 208
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 209
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 211
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 214
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 216
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 218
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
# Review: 222
# Sentiments: {22: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 64: 'neutral', 65: 'neutral', 72: 'neutral', 103: 'neutral', 104: 'neutral', 110: 'neutral', 113: 'neutral', 146: 'neutral', 154: 'neutral', 156: 'neutral', 163: 'neutral', 165: 'neutral', 168: 'neutral', 170: 'neutral', 175: 'neutral', 178: 'neutral', 184: 'neutral', 186: 'neutral', 193: 'neutral', 216: 'neutral', 218: 'neutral', 223: 'neutral'}
#
# Review: 18
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 36
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 38
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 42
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 63
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 86
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 101
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 103
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 116
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 118
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 119
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 121
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 132
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 133
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 147
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 152
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 162
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 165
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 183
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 189
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 202
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 213
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 223
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
# Review: 224
# Sentiments: {26: 'neutral', 35: 'neutral', 83: 'neutral', 112: 'neutral', 116: 'neutral', 117: 'neutral', 127: 'neutral', 128: 'neutral', 132: 'neutral', 135: 'neutral', 140: 'neutral', 143: 'neutral', 145: 'neutral', 159: 'neutral', 160: 'neutral', 164: 'neutral', 173: 'neutral', 196: 'neutral', 201: 'neutral', 203: 'neutral', 208: 'neutral', 209: 'neutral', 211: 'neutral', 214: 'neutral', 216: 'neutral', 218: 'neutral', 222: 'neutral'}
