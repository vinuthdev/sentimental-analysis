# %%
import pandas as pd
import json

with open('C:\\Users\\vinut\\Desktop\\DataMining Project\\Software_5.json') as f:
    data = [json.loads(line) for line in f]
df = pd.DataFrame(data)
df.to_csv('output.csv', index=False)

# %%
df = pd.read_csv('output.csv')
df_sorted = df.sort_values(by='asin')
asin_counts = df_sorted['asin'].value_counts()
unique = asin_counts.index.tolist()
count = asin_counts.values.tolist()
unique_asin_data = pd.DataFrame({'asin': unique, 'count': count})
print("Unique values and their counts:")
print(unique_asin_data)

sum_hundred = asin_counts.head(100).sum()
print("Sum of the first 100 counts:", sum_hundred)
# Out:
# Unique values and their counts:
#            asin  count
# 0    B0000AZJY6    452
# 1    B000EORV8Q    232
# 2    B0001FS9NE    230
# 3    B000050ZRE    230
# 4    B00EZPXYP4     98
# ..          ...    ...
# 797  B0011SFXCK      1
# 798  B00149YSUY      1
# 799  B0012KW3KM      1
# 800  B00132DENO      1
# 801  B0015CA9VW      1
#
# [802 rows x 2 columns]
# Sum of the first 100 counts: 4938

# %%
import pandas as pd

# Assuming your data is in a DataFrame named 'df'
# Replace 'your_dataset.csv' with your actual dataset filename
df = pd.read_csv('output.csv')

# Filter data for 'B0000AZJY6'
filtered_data = df[df['asin'] == 'B00F8K9MZQ']

# Save filtered data to a new file
filtered_data.to_csv('B00F8K9MZQ_data.csv', index=False)

# %%
df4 = pd.read_csv('C:\\Users\\vinut\\Desktop\\DataMining Project\\B00F8K9MZQ_data.csv')

df4.head(5)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      5.0      True   12 2, 2013  A3H1L8J408EMXK  B00F8K9MZQ
# 1      5.0      True  11 26, 2013  A1X1CEGHTHMBL1  B00F8K9MZQ
# 2      5.0      True  04 13, 2016  A2SQZL4FSRTKA6  B00F8K9MZQ
# 3      4.0      True   12 2, 2015  A1DPOEBIUY9IVI  B00F8K9MZQ
# 4      5.0      True  07 17, 2015  A2ZFQ9RT9Y9NQN  B00F8K9MZQ
#
#                            style  reviewerName  \
# 0  {'Platform:': ' PC/Mac Disc'}  Great Poobah
# 1  {'Platform:': ' PC/Mac Disc'}         JJCEO
# 2  {'Platform:': ' PC/Mac Disc'}     Roy Batty
# 3  {'Platform:': ' PC/Mac Disc'}        Vishwa
# 4  {'Platform:': ' PC/Mac Disc'}       rigilsp
#
#                                           reviewText  \
# 0  I've used Turbotax since it first came out and...
# 1  I do our taxes every year and it is a tedious ...
# 2                   Always good, easy, and accurate.
# 3                                          satisfied
# 4                               Filed without issue.
#
#                                              summary  unixReviewTime   vote  \
# 0                                   An excellent buy      1385942400    4.0
# 1  A solid and reliable tax software program that...      1385424000  127.0
# 2                                         Five Stars      1460505600    NaN
# 3                                         Four Stars      1449014400    NaN
# 4                                          It worked      1437091200    NaN
#
#    image
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
print(df4.columns)
# Out:
# Index(['overall', 'verified', 'reviewTime', 'reviewerID', 'asin', 'style',
#        'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'vote',
#        'image'],
#       dtype='object')

# %%
columns_to_remove = ['image', 'style']
df4 = df4.drop(columns=columns_to_remove)
df4.head(5)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  reviewerName  \
# 0      5.0      True   12 2, 2013  A3H1L8J408EMXK  B00F8K9MZQ  Great Poobah
# 1      5.0      True  11 26, 2013  A1X1CEGHTHMBL1  B00F8K9MZQ         JJCEO
# 2      5.0      True  04 13, 2016  A2SQZL4FSRTKA6  B00F8K9MZQ     Roy Batty
# 3      4.0      True   12 2, 2015  A1DPOEBIUY9IVI  B00F8K9MZQ        Vishwa
# 4      5.0      True  07 17, 2015  A2ZFQ9RT9Y9NQN  B00F8K9MZQ       rigilsp
#
#                                           reviewText  \
# 0  I've used Turbotax since it first came out and...
# 1  I do our taxes every year and it is a tedious ...
# 2                   Always good, easy, and accurate.
# 3                                          satisfied
# 4                               Filed without issue.
#
#                                              summary  unixReviewTime   vote
# 0                                   An excellent buy      1385942400    4.0
# 1  A solid and reliable tax software program that...      1385424000  127.0
# 2                                         Five Stars      1460505600    NaN
# 3                                         Four Stars      1449014400    NaN
# 4                                          It worked      1437091200    NaN

# %%
null = df4.isnull().sum()
print(null)
# Out:
# overall            0
# verified           0
# reviewTime         0
# reviewerID         0
# asin               0
# reviewerName       0
# reviewText         0
# summary            0
# unixReviewTime     0
# vote              67
# dtype: int64

# %%
df4['summary'].fillna('No summary', inplace=True)
df4['vote'].fillna(0, inplace=True)
null2 = df4.isnull().sum()
print(null2)
# Out:
# overall           0
# verified          0
# reviewTime        0
# reviewerID        0
# asin              0
# reviewerName      0
# reviewText        0
# summary           0
# unixReviewTime    0
# vote              0
# dtype: int64

# %%
count = df4['verified'].value_counts()
print(count)
# Out:
# verified
# True     67
# False     7
# Name: count, dtype: int64

# %%
columns_to_remove = ['unixReviewTime', 'reviewTime','reviewerName','verified','vote']
df4 = df4.drop(columns=columns_to_remove)
df4.head(5)
# Out:
#    overall      reviewerID        asin  \
# 0      5.0  A3H1L8J408EMXK  B00F8K9MZQ
# 1      5.0  A1X1CEGHTHMBL1  B00F8K9MZQ
# 2      5.0  A2SQZL4FSRTKA6  B00F8K9MZQ
# 3      4.0  A1DPOEBIUY9IVI  B00F8K9MZQ
# 4      5.0  A2ZFQ9RT9Y9NQN  B00F8K9MZQ
#
#                                           reviewText  \
# 0  I've used Turbotax since it first came out and...
# 1  I do our taxes every year and it is a tedious ...
# 2                   Always good, easy, and accurate.
# 3                                          satisfied
# 4                               Filed without issue.
#
#                                              summary
# 0                                   An excellent buy
# 1  A solid and reliable tax software program that...
# 2                                         Five Stars
# 3                                         Four Stars
# 4                                          It worked

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vinut\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def tokenize_text(text):
    tokens = word_tokenize(str(text))  # Tokenize the text
    return tokens

# %%
# Tokenizing 'reviewText' column
df4['reviewText'] = df4['reviewText'].apply(tokenize_text)

# Tokenizing 'summary' column
df4['summary'] = df4['summary'].apply(tokenize_text)

print()

# %%
# printing reviewText 
print("Tokenized Review Text:")
for index, tokens in enumerate(df4['reviewText'].head(), start=1):
    print(f"Row {index}: {tokens}")

# Printing tokenized summary
print("\nTokenized Summary:")
for index, tokens in enumerate(df4['summary'].head(), start=1):
    print(f"Row {index}: {tokens}")
# Out:
# Tokenized Review Text:
# Row 1: ['I', "'ve", 'used', 'Turbotax', 'since', 'it', 'first', 'came', 'out', 'and', 'find', 'it', 'an', 'excellent', 'buy', '.', 'Most', 'people', 'using', 'an', 'accountant', 'would', 'save', 'a', 'bunch', 'of', 'money', 'using', 'it', '.', 'It', 'has', 'an', 'easy', 'step', 'process', 'that', 'walks', 'you', 'through', 'the', 'entire', 'process', 'and', 'your', 'state', 'tax', 'is', 'automatically', 'prepared', 'as', 'you', 'prepare', 'your', 'federal', 'tax', '.', 'A', 'friend', 'tried', 'it', 'recreating', 'his', 'tax', 'that', 'had', 'been', 'prepared', 'by', 'his', 'accountant', 'and', 'found', 'Turbotax', 'lowered', 'his', 'tax', '.']
# Row 2: ['I', 'do', 'our', 'taxes', 'every', 'year', 'and', 'it', 'is', 'a', 'tedious', 'job', '.', 'If', 'it', 'was', "n't", 'for', 'TurboTax', 'I', 'probably', 'would', 'have', 'it', 'done', '.', 'This', 'year', "'s", 'version', 'is', 'pretty', 'much', 'the', 'same', 'as', 'past', 'years', 'and', 'I', 'am', 'glad', 'because', 'I', 'have', 'used', 'the', 'software', 'for', 'as', 'long', 'as', 'I', 'can', 'remember', 'and', 'I', 'like', 'following', 'the', 'same', 'walk', 'through', 'routine', 'that', 'TurboTax', 'makes', 'you', 'follow', '.', 'Using', 'TurboTax', 'is', 'fast', 'and', 'easy', 'and', 'I', 'like', 'several', 'features', 'that', 'I', 'use', 'every', 'year', ':', '*', 'The', 'ability', 'to', 'import', 'last', 'year', "'s", 'data', 'automatically', 'into', 'this', 'year', "'s", 'preparation', '.', '*', 'The', 'ability', 'to', 'E-file', 'your', 'taxes', 'with', 'the', 'federal', 'government', 'which', 'speeds', 'up', 'your', 'refund', ',', 'if', 'you', 'are', 'getting', 'one', '.', '*', 'The', 'itemized', 'deductions', 'for', 'gifts', 'to', 'charity', 'is', 'very', 'helpful', 'as', 'we', 'donate', 'quite', 'a', 'bit', 'every', 'year', 'and', 'it', 'makes', 'it', 'easier', 'to', 'compile', 'a', 'list', ',', 'keep', 'it', 'for', 'your', 'records', 'and', 'come', 'up', 'with', 'a', 'reasonable', 'value', 'to', 'claim', 'on', 'your', 'taxes', '.', '*', 'I', 'actually', 'pre-calculate', 'my', 'next', 'year', "'s", 'taxes', 'and', 'print', 'out', 'the', 'forms', 'to', 'mail', 'in', 'quarterly', 'payments', 'for', 'the', 'next', 'year', "'s", 'taxes', 'to', 'avoid', 'a', 'penalty', '.', '*', 'The', 'ability', 'to', 'keep', 'a', 'PDF', 'copy', 'of', 'your', 'tax', 'return', 'forms', 'for', 'your', 'records', 'as', 'well', 'as', 'print', 'out', 'the', 'forms', 'it', 'you', 'need', 'them', '.', '*', 'I', 'always', 'save', 'my', 'tax', 'computer', 'files', 'and', 'I', 'buy', 'the', 'disk', 'version', 'of', 'TurboTax', 'in', 'case', 'I', 'have', 'to', 'reinstall', 'the', 'software', 'and', 'make', 'an', 'update', 'or', 'file', 'an', 'amended', 'tax', 'return', 'later', 'on', '.', 'The', 'nice', 'thing', 'is', 'that', 'you', 'can', 'update', 'the', 'program', 'and', 'make', 'sure', 'that', 'you', 'have', 'all', 'of', 'the', 'latest', 'updates', 'to', 'the', 'tax', 'laws', 'and', 'forms', '.', 'Having', 'TurboTax', 'walks', 'me', 'through', 'the', 'forms', 'and', 'helps', 'me', 'fill', 'them', 'out', 'faster', 'and', 'easier', 'than', 'reading', 'all', 'of', 'those', 'tax', 'pages', 'written', 'for', 'lawyers', '.', 'I', 'just', 'use', 'the', 'combined', 'federal', 'and', 'state', 'version', 'of', 'TurboTax', 'and', 'file', 'electronically', '.', 'This', 'version', 'includes', 'the', 'ability', 'to', 'file', 'up', 'to', '5', 'Federal', 'tax', 'reports', 'electronically', '.', 'You', 'can', 'download', 'the', 'state', 'version', 'of', 'TurboTax', 'for', 'one', 'state', 'for', 'free', '.', 'If', 'you', 'want', 'to', 'file', 'your', 'state', 'return', 'electronically', 'then', 'you', 'have', 'to', 'pay', 'for', 'the', 'privilege', '.', 'I', 'like', 'the', 'fact', 'that', 'I', 'can', 'quickly', 'do', 'my', 'state', 'taxes', 'after', 'finishing', 'the', 'federal', 'forms', '.', 'I', 'also', 'always', 'estimate', 'my', 'next', 'year', "'s", 'taxes', 'and', 'print', 'out', 'the', 'prepayment', 'forms', 'that', 'I', 'customize', 'to', 'fit', 'what', 'additional', 'income', 'I', 'am', 'expecting', '.', 'These', 'are', 'just', 'a', 'few', 'of', 'the', 'main', 'features', 'that', 'I', 'like', 'with', 'TurboTax', 'and', 'I', 'recommend', 'the', 'software', 'to', 'you', 'as', 'an', 'easy', 'tool', 'to', 'use', '.', 'I', 'do', 'wait', 'to', 'find', 'a', 'good', 'price', 'on', 'it', 'as', 'the', 'price', 'keeps', 'going', 'up', 'and', 'up', 'every', 'year', '.']
# Row 3: ['Always', 'good', ',', 'easy', ',', 'and', 'accurate', '.']
# Row 4: ['satisfied']
# Row 5: ['Filed', 'without', 'issue', '.']
#
# Tokenized Summary:
# Row 1: ['An', 'excellent', 'buy']
# Row 2: ['A', 'solid', 'and', 'reliable', 'tax', 'software', 'program', 'that', 'I', 'have', 'used', 'for', 'many', 'years', '!']
# Row 3: ['Five', 'Stars']
# Row 4: ['Four', 'Stars']
# Row 5: ['It', 'worked']

# %%
df4['reviewText'] = df4['reviewText'].apply(lambda tokens: [token.lower() for token in tokens])

df4['summary'] = df4['summary'].apply(lambda tokens: [token.lower() for token in tokens])

# %%
print("Lowercase Tokens for Review Text:")
for index, tokens in enumerate(df4['reviewText'].head(), start=1):
    print(f"Row {index}: {tokens}")

print("\nLowercase Tokens for Summary:")
for index, tokens in enumerate(df4['summary'].head(), start=1):
    print(f"Row {index}: {tokens}")
# Out:
# Lowercase Tokens for Review Text:
# Row 1: ['i', "'ve", 'used', 'turbotax', 'since', 'it', 'first', 'came', 'out', 'and', 'find', 'it', 'an', 'excellent', 'buy', '.', 'most', 'people', 'using', 'an', 'accountant', 'would', 'save', 'a', 'bunch', 'of', 'money', 'using', 'it', '.', 'it', 'has', 'an', 'easy', 'step', 'process', 'that', 'walks', 'you', 'through', 'the', 'entire', 'process', 'and', 'your', 'state', 'tax', 'is', 'automatically', 'prepared', 'as', 'you', 'prepare', 'your', 'federal', 'tax', '.', 'a', 'friend', 'tried', 'it', 'recreating', 'his', 'tax', 'that', 'had', 'been', 'prepared', 'by', 'his', 'accountant', 'and', 'found', 'turbotax', 'lowered', 'his', 'tax', '.']
# Row 2: ['i', 'do', 'our', 'taxes', 'every', 'year', 'and', 'it', 'is', 'a', 'tedious', 'job', '.', 'if', 'it', 'was', "n't", 'for', 'turbotax', 'i', 'probably', 'would', 'have', 'it', 'done', '.', 'this', 'year', "'s", 'version', 'is', 'pretty', 'much', 'the', 'same', 'as', 'past', 'years', 'and', 'i', 'am', 'glad', 'because', 'i', 'have', 'used', 'the', 'software', 'for', 'as', 'long', 'as', 'i', 'can', 'remember', 'and', 'i', 'like', 'following', 'the', 'same', 'walk', 'through', 'routine', 'that', 'turbotax', 'makes', 'you', 'follow', '.', 'using', 'turbotax', 'is', 'fast', 'and', 'easy', 'and', 'i', 'like', 'several', 'features', 'that', 'i', 'use', 'every', 'year', ':', '*', 'the', 'ability', 'to', 'import', 'last', 'year', "'s", 'data', 'automatically', 'into', 'this', 'year', "'s", 'preparation', '.', '*', 'the', 'ability', 'to', 'e-file', 'your', 'taxes', 'with', 'the', 'federal', 'government', 'which', 'speeds', 'up', 'your', 'refund', ',', 'if', 'you', 'are', 'getting', 'one', '.', '*', 'the', 'itemized', 'deductions', 'for', 'gifts', 'to', 'charity', 'is', 'very', 'helpful', 'as', 'we', 'donate', 'quite', 'a', 'bit', 'every', 'year', 'and', 'it', 'makes', 'it', 'easier', 'to', 'compile', 'a', 'list', ',', 'keep', 'it', 'for', 'your', 'records', 'and', 'come', 'up', 'with', 'a', 'reasonable', 'value', 'to', 'claim', 'on', 'your', 'taxes', '.', '*', 'i', 'actually', 'pre-calculate', 'my', 'next', 'year', "'s", 'taxes', 'and', 'print', 'out', 'the', 'forms', 'to', 'mail', 'in', 'quarterly', 'payments', 'for', 'the', 'next', 'year', "'s", 'taxes', 'to', 'avoid', 'a', 'penalty', '.', '*', 'the', 'ability', 'to', 'keep', 'a', 'pdf', 'copy', 'of', 'your', 'tax', 'return', 'forms', 'for', 'your', 'records', 'as', 'well', 'as', 'print', 'out', 'the', 'forms', 'it', 'you', 'need', 'them', '.', '*', 'i', 'always', 'save', 'my', 'tax', 'computer', 'files', 'and', 'i', 'buy', 'the', 'disk', 'version', 'of', 'turbotax', 'in', 'case', 'i', 'have', 'to', 'reinstall', 'the', 'software', 'and', 'make', 'an', 'update', 'or', 'file', 'an', 'amended', 'tax', 'return', 'later', 'on', '.', 'the', 'nice', 'thing', 'is', 'that', 'you', 'can', 'update', 'the', 'program', 'and', 'make', 'sure', 'that', 'you', 'have', 'all', 'of', 'the', 'latest', 'updates', 'to', 'the', 'tax', 'laws', 'and', 'forms', '.', 'having', 'turbotax', 'walks', 'me', 'through', 'the', 'forms', 'and', 'helps', 'me', 'fill', 'them', 'out', 'faster', 'and', 'easier', 'than', 'reading', 'all', 'of', 'those', 'tax', 'pages', 'written', 'for', 'lawyers', '.', 'i', 'just', 'use', 'the', 'combined', 'federal', 'and', 'state', 'version', 'of', 'turbotax', 'and', 'file', 'electronically', '.', 'this', 'version', 'includes', 'the', 'ability', 'to', 'file', 'up', 'to', '5', 'federal', 'tax', 'reports', 'electronically', '.', 'you', 'can', 'download', 'the', 'state', 'version', 'of', 'turbotax', 'for', 'one', 'state', 'for', 'free', '.', 'if', 'you', 'want', 'to', 'file', 'your', 'state', 'return', 'electronically', 'then', 'you', 'have', 'to', 'pay', 'for', 'the', 'privilege', '.', 'i', 'like', 'the', 'fact', 'that', 'i', 'can', 'quickly', 'do', 'my', 'state', 'taxes', 'after', 'finishing', 'the', 'federal', 'forms', '.', 'i', 'also', 'always', 'estimate', 'my', 'next', 'year', "'s", 'taxes', 'and', 'print', 'out', 'the', 'prepayment', 'forms', 'that', 'i', 'customize', 'to', 'fit', 'what', 'additional', 'income', 'i', 'am', 'expecting', '.', 'these', 'are', 'just', 'a', 'few', 'of', 'the', 'main', 'features', 'that', 'i', 'like', 'with', 'turbotax', 'and', 'i', 'recommend', 'the', 'software', 'to', 'you', 'as', 'an', 'easy', 'tool', 'to', 'use', '.', 'i', 'do', 'wait', 'to', 'find', 'a', 'good', 'price', 'on', 'it', 'as', 'the', 'price', 'keeps', 'going', 'up', 'and', 'up', 'every', 'year', '.']
# Row 3: ['always', 'good', ',', 'easy', ',', 'and', 'accurate', '.']
# Row 4: ['satisfied']
# Row 5: ['filed', 'without', 'issue', '.']
#
# Lowercase Tokens for Summary:
# Row 1: ['an', 'excellent', 'buy']
# Row 2: ['a', 'solid', 'and', 'reliable', 'tax', 'software', 'program', 'that', 'i', 'have', 'used', 'for', 'many', 'years', '!']
# Row 3: ['five', 'stars']
# Row 4: ['four', 'stars']
# Row 5: ['it', 'worked']

# %%
import re

# Function to remove special characters and spaces from tokens
def remove_special_characters(tokens):
    # Define regex pattern to remove spaces and special characters
    pattern = r'[^a-zA-Z0-9]'  # Keeps letters and numbers
    
    # Remove special characters and spaces using regex
    tokens_no_special = [re.sub(pattern, '', token) for token in tokens]
    tokens_no_special = [token for token in tokens_no_special if token]  # Remove empty strings
    return tokens_no_special

# Remove special characters and spaces from 'reviewText' column
df4['reviewText'] = df4['reviewText'].apply(remove_special_characters)

# Remove special characters and spaces from 'summary' column
df4['summary'] = df4['summary'].apply(remove_special_characters)

# %%
# Print tokens with special characters removed for 'reviewText_tokens_clean' column
print("Tokens with Special Characters Removed for Review Text:")
for index, tokens in enumerate(df4['reviewText'].head(), start=1):
    print(f"Row {index}: {tokens}")

# Print tokens with special characters removed for 'summary_tokens_clean' column
print("\nTokens with Special Characters Removed for Summary:")
for index, tokens in enumerate(df4['summary'].head(), start=1):
    print(f"Row {index}: {tokens}")
# Out:
# Tokens with Special Characters Removed for Review Text:
# Row 1: ['i', 've', 'used', 'turbotax', 'since', 'it', 'first', 'came', 'out', 'and', 'find', 'it', 'an', 'excellent', 'buy', 'most', 'people', 'using', 'an', 'accountant', 'would', 'save', 'a', 'bunch', 'of', 'money', 'using', 'it', 'it', 'has', 'an', 'easy', 'step', 'process', 'that', 'walks', 'you', 'through', 'the', 'entire', 'process', 'and', 'your', 'state', 'tax', 'is', 'automatically', 'prepared', 'as', 'you', 'prepare', 'your', 'federal', 'tax', 'a', 'friend', 'tried', 'it', 'recreating', 'his', 'tax', 'that', 'had', 'been', 'prepared', 'by', 'his', 'accountant', 'and', 'found', 'turbotax', 'lowered', 'his', 'tax']
# Row 2: ['i', 'do', 'our', 'taxes', 'every', 'year', 'and', 'it', 'is', 'a', 'tedious', 'job', 'if', 'it', 'was', 'nt', 'for', 'turbotax', 'i', 'probably', 'would', 'have', 'it', 'done', 'this', 'year', 's', 'version', 'is', 'pretty', 'much', 'the', 'same', 'as', 'past', 'years', 'and', 'i', 'am', 'glad', 'because', 'i', 'have', 'used', 'the', 'software', 'for', 'as', 'long', 'as', 'i', 'can', 'remember', 'and', 'i', 'like', 'following', 'the', 'same', 'walk', 'through', 'routine', 'that', 'turbotax', 'makes', 'you', 'follow', 'using', 'turbotax', 'is', 'fast', 'and', 'easy', 'and', 'i', 'like', 'several', 'features', 'that', 'i', 'use', 'every', 'year', 'the', 'ability', 'to', 'import', 'last', 'year', 's', 'data', 'automatically', 'into', 'this', 'year', 's', 'preparation', 'the', 'ability', 'to', 'efile', 'your', 'taxes', 'with', 'the', 'federal', 'government', 'which', 'speeds', 'up', 'your', 'refund', 'if', 'you', 'are', 'getting', 'one', 'the', 'itemized', 'deductions', 'for', 'gifts', 'to', 'charity', 'is', 'very', 'helpful', 'as', 'we', 'donate', 'quite', 'a', 'bit', 'every', 'year', 'and', 'it', 'makes', 'it', 'easier', 'to', 'compile', 'a', 'list', 'keep', 'it', 'for', 'your', 'records', 'and', 'come', 'up', 'with', 'a', 'reasonable', 'value', 'to', 'claim', 'on', 'your', 'taxes', 'i', 'actually', 'precalculate', 'my', 'next', 'year', 's', 'taxes', 'and', 'print', 'out', 'the', 'forms', 'to', 'mail', 'in', 'quarterly', 'payments', 'for', 'the', 'next', 'year', 's', 'taxes', 'to', 'avoid', 'a', 'penalty', 'the', 'ability', 'to', 'keep', 'a', 'pdf', 'copy', 'of', 'your', 'tax', 'return', 'forms', 'for', 'your', 'records', 'as', 'well', 'as', 'print', 'out', 'the', 'forms', 'it', 'you', 'need', 'them', 'i', 'always', 'save', 'my', 'tax', 'computer', 'files', 'and', 'i', 'buy', 'the', 'disk', 'version', 'of', 'turbotax', 'in', 'case', 'i', 'have', 'to', 'reinstall', 'the', 'software', 'and', 'make', 'an', 'update', 'or', 'file', 'an', 'amended', 'tax', 'return', 'later', 'on', 'the', 'nice', 'thing', 'is', 'that', 'you', 'can', 'update', 'the', 'program', 'and', 'make', 'sure', 'that', 'you', 'have', 'all', 'of', 'the', 'latest', 'updates', 'to', 'the', 'tax', 'laws', 'and', 'forms', 'having', 'turbotax', 'walks', 'me', 'through', 'the', 'forms', 'and', 'helps', 'me', 'fill', 'them', 'out', 'faster', 'and', 'easier', 'than', 'reading', 'all', 'of', 'those', 'tax', 'pages', 'written', 'for', 'lawyers', 'i', 'just', 'use', 'the', 'combined', 'federal', 'and', 'state', 'version', 'of', 'turbotax', 'and', 'file', 'electronically', 'this', 'version', 'includes', 'the', 'ability', 'to', 'file', 'up', 'to', '5', 'federal', 'tax', 'reports', 'electronically', 'you', 'can', 'download', 'the', 'state', 'version', 'of', 'turbotax', 'for', 'one', 'state', 'for', 'free', 'if', 'you', 'want', 'to', 'file', 'your', 'state', 'return', 'electronically', 'then', 'you', 'have', 'to', 'pay', 'for', 'the', 'privilege', 'i', 'like', 'the', 'fact', 'that', 'i', 'can', 'quickly', 'do', 'my', 'state', 'taxes', 'after', 'finishing', 'the', 'federal', 'forms', 'i', 'also', 'always', 'estimate', 'my', 'next', 'year', 's', 'taxes', 'and', 'print', 'out', 'the', 'prepayment', 'forms', 'that', 'i', 'customize', 'to', 'fit', 'what', 'additional', 'income', 'i', 'am', 'expecting', 'these', 'are', 'just', 'a', 'few', 'of', 'the', 'main', 'features', 'that', 'i', 'like', 'with', 'turbotax', 'and', 'i', 'recommend', 'the', 'software', 'to', 'you', 'as', 'an', 'easy', 'tool', 'to', 'use', 'i', 'do', 'wait', 'to', 'find', 'a', 'good', 'price', 'on', 'it', 'as', 'the', 'price', 'keeps', 'going', 'up', 'and', 'up', 'every', 'year']
# Row 3: ['always', 'good', 'easy', 'and', 'accurate']
# Row 4: ['satisfied']
# Row 5: ['filed', 'without', 'issue']
#
# Tokens with Special Characters Removed for Summary:
# Row 1: ['an', 'excellent', 'buy']
# Row 2: ['a', 'solid', 'and', 'reliable', 'tax', 'software', 'program', 'that', 'i', 'have', 'used', 'for', 'many', 'years']
# Row 3: ['five', 'stars']
# Row 4: ['four', 'stars']
# Row 5: ['it', 'worked']

# %%
import nltk
from nltk.corpus import stopwords

# Download NLTK stopwords if not downloaded
nltk.download('stopwords')

# Get English stopwords from NLTK
stop_words = set(stopwords.words('english'))

# Function to remove stopwords from tokens
def remove_stopwords(tokens):
    tokens_no_stop = [token for token in tokens if token not in stop_words]
    return tokens_no_stop

# Remove stopwords from 'reviewText_tokens_no_punct' column
df4['reviewText'] = df4['reviewText'].apply(remove_stopwords)

# Remove stopwords from 'summary_tokens_no_punct' column
df4['summary'] = df4['summary'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vinut\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Print tokens without stopwords for 'reviewText_tokens_no_stop' column
print("Tokens without Stopwords for Review Text:")
for index, tokens in enumerate(df4['reviewText'].head(), start=1):
    print(f"Row {index}: {tokens}")

# Print tokens without stopwords for 'summary_tokens_no_stop' column
print("\nTokens without Stopwords for Summary:")
for index, tokens in enumerate(df4['summary'].head(), start=1):
    print(f"Row {index}: {tokens}")
# Out:
# Tokens without Stopwords for Review Text:
# Row 1: ['used', 'turbotax', 'since', 'first', 'came', 'find', 'excellent', 'buy', 'people', 'using', 'accountant', 'would', 'save', 'bunch', 'money', 'using', 'easy', 'step', 'process', 'walks', 'entire', 'process', 'state', 'tax', 'automatically', 'prepared', 'prepare', 'federal', 'tax', 'friend', 'tried', 'recreating', 'tax', 'prepared', 'accountant', 'found', 'turbotax', 'lowered', 'tax']
# Row 2: ['taxes', 'every', 'year', 'tedious', 'job', 'nt', 'turbotax', 'probably', 'would', 'done', 'year', 'version', 'pretty', 'much', 'past', 'years', 'glad', 'used', 'software', 'long', 'remember', 'like', 'following', 'walk', 'routine', 'turbotax', 'makes', 'follow', 'using', 'turbotax', 'fast', 'easy', 'like', 'several', 'features', 'use', 'every', 'year', 'ability', 'import', 'last', 'year', 'data', 'automatically', 'year', 'preparation', 'ability', 'efile', 'taxes', 'federal', 'government', 'speeds', 'refund', 'getting', 'one', 'itemized', 'deductions', 'gifts', 'charity', 'helpful', 'donate', 'quite', 'bit', 'every', 'year', 'makes', 'easier', 'compile', 'list', 'keep', 'records', 'come', 'reasonable', 'value', 'claim', 'taxes', 'actually', 'precalculate', 'next', 'year', 'taxes', 'print', 'forms', 'mail', 'quarterly', 'payments', 'next', 'year', 'taxes', 'avoid', 'penalty', 'ability', 'keep', 'pdf', 'copy', 'tax', 'return', 'forms', 'records', 'well', 'print', 'forms', 'need', 'always', 'save', 'tax', 'computer', 'files', 'buy', 'disk', 'version', 'turbotax', 'case', 'reinstall', 'software', 'make', 'update', 'file', 'amended', 'tax', 'return', 'later', 'nice', 'thing', 'update', 'program', 'make', 'sure', 'latest', 'updates', 'tax', 'laws', 'forms', 'turbotax', 'walks', 'forms', 'helps', 'fill', 'faster', 'easier', 'reading', 'tax', 'pages', 'written', 'lawyers', 'use', 'combined', 'federal', 'state', 'version', 'turbotax', 'file', 'electronically', 'version', 'includes', 'ability', 'file', '5', 'federal', 'tax', 'reports', 'electronically', 'download', 'state', 'version', 'turbotax', 'one', 'state', 'free', 'want', 'file', 'state', 'return', 'electronically', 'pay', 'privilege', 'like', 'fact', 'quickly', 'state', 'taxes', 'finishing', 'federal', 'forms', 'also', 'always', 'estimate', 'next', 'year', 'taxes', 'print', 'prepayment', 'forms', 'customize', 'fit', 'additional', 'income', 'expecting', 'main', 'features', 'like', 'turbotax', 'recommend', 'software', 'easy', 'tool', 'use', 'wait', 'find', 'good', 'price', 'price', 'keeps', 'going', 'every', 'year']
# Row 3: ['always', 'good', 'easy', 'accurate']
# Row 4: ['satisfied']
# Row 5: ['filed', 'without', 'issue']
#
# Tokens without Stopwords for Summary:
# Row 1: ['excellent', 'buy']
# Row 2: ['solid', 'reliable', 'tax', 'software', 'program', 'used', 'many', 'years']
# Row 3: ['five', 'stars']
# Row 4: ['four', 'stars']
# Row 5: ['worked']

# %%
df4
# Out:
#     overall      reviewerID        asin  \
# 0       5.0  A3H1L8J408EMXK  B00F8K9MZQ
# 1       5.0  A1X1CEGHTHMBL1  B00F8K9MZQ
# 2       5.0  A2SQZL4FSRTKA6  B00F8K9MZQ
# 3       4.0  A1DPOEBIUY9IVI  B00F8K9MZQ
# 4       5.0  A2ZFQ9RT9Y9NQN  B00F8K9MZQ
# ..      ...             ...         ...
# 69      5.0  A3MJYAJ5JO38QZ  B00F8K9MZQ
# 70      5.0  A207F6AQXEJ4XA  B00F8K9MZQ
# 71      1.0   A6IVWNRAEYIOW  B00F8K9MZQ
# 72      5.0  A1DSGNHMAGNLTZ  B00F8K9MZQ
# 73      5.0  A28HBQ7BP70VGL  B00F8K9MZQ
#
#                                            reviewText  \
# 0   [used, turbotax, since, first, came, find, exc...
# 1   [taxes, every, year, tedious, job, nt, turbota...
# 2                      [always, good, easy, accurate]
# 3                                         [satisfied]
# 4                             [filed, without, issue]
# ..                                                ...
# 69  [love, turbo, tax, used, many, years, always, ...
# 70  [ttax2013, solid, fast, prior, taxyear, versio...
# 71  [buy, product, go, turbotax, site, look, 1603,...
# 72                                          [perfecr]
# 73                               [received, expected]
#
#                                               summary
# 0                                    [excellent, buy]
# 1   [solid, reliable, tax, software, program, used...
# 2                                       [five, stars]
# 3                                       [four, stars]
# 4                                            [worked]
# ..                                                ...
# 69                     [always, superior, every, way]
# 70            [turbotax, deluxe, 2013, fedstateefile]
# 71             [turbotax, deluxe, 2013, pc, download]
# 72                                      [five, stars]
# 73                                      [five, stars]
#
# [74 rows x 5 columns]

# %%
# Function to get sentiment polarity
from textblob import TextBlob
def get_sentiment(text):
    analysis = TextBlob(str(text))
    return analysis.sentiment.polarity
df4['sentiment'] = df4['reviewText'].apply(get_sentiment)
print(df4[['reviewText', 'sentiment']].head(10))
# Out:
#                                           reviewText  sentiment
# 0  [used, turbotax, since, first, came, find, exc...   0.420833
# 1  [taxes, every, year, tedious, job, nt, turbota...   0.192667
# 2                     [always, good, easy, accurate]   0.511111
# 3                                        [satisfied]   0.500000
# 4                            [filed, without, issue]   0.000000
# 5  [use, turbo, tax, every, year, taxes, disappoi...   0.150000
# 6                              [best, tax, software]   1.000000
# 7                                             [good]   0.700000
# 8                            [delivered, advertised]   0.000000
# 9  [2013, version, used, turbotax, taxcut, years,...   0.366667

# %%
# Function to convert sentiment scores to categorical values
def get_sentiment_category(score):
    if score >= 0.3:  
        return 1  # Positive sentiment
    elif score < -0.1:
        return -1  # Negative sentiment
    else:
        return 0  # Neutral sentiment or no strong sentiment
df4['sentiment_category'] = df4['sentiment'].apply(get_sentiment_category)
df4.head(50)
# Out:
#     overall      reviewerID        asin  \
# 0       5.0  A3H1L8J408EMXK  B00F8K9MZQ
# 1       5.0  A1X1CEGHTHMBL1  B00F8K9MZQ
# 2       5.0  A2SQZL4FSRTKA6  B00F8K9MZQ
# 3       4.0  A1DPOEBIUY9IVI  B00F8K9MZQ
# 4       5.0  A2ZFQ9RT9Y9NQN  B00F8K9MZQ
# 5       3.0  A20OIY9CQ4S5JI  B00F8K9MZQ
# 6       5.0  A1UQOCC5QU9GCU  B00F8K9MZQ
# 7       5.0  A21YKKGDHH4YAL  B00F8K9MZQ
# 8       4.0   AUEUB778AU7MW  B00F8K9MZQ
# 9       3.0   A6T2B13WYCMJG  B00F8K9MZQ
# 10      5.0   A5G3GY4XV6E7A  B00F8K9MZQ
# 11      5.0  A1RGW8ZYX0PAE1  B00F8K9MZQ
# 12      5.0  A235X21ECO1W4R  B00F8K9MZQ
# 13      4.0  A1I9Z7BQW5ZD0S  B00F8K9MZQ
# 14      4.0  A2KIZOKNM0A1JG  B00F8K9MZQ
# 15      5.0  A3C2O6SS4ITQHC  B00F8K9MZQ
# 16      4.0  A1Z2IWNP7IHKCC  B00F8K9MZQ
# 17      5.0  A2PXBHHYYF5OQB  B00F8K9MZQ
# 18      4.0   A3IJ4Z18FTIIP  B00F8K9MZQ
# 19      5.0  A3OKJR8V2MR3Z9  B00F8K9MZQ
# 20      4.0   AFJUSRQTNHJ5I  B00F8K9MZQ
# 21      5.0  A2N2XU3U2LYUZS  B00F8K9MZQ
# 22      4.0  A3JP831AUTAFB7  B00F8K9MZQ
# 23      4.0  A33IUIT8G4MA4N  B00F8K9MZQ
# 24      5.0   ADWUJZ8865J2A  B00F8K9MZQ
# 25      5.0  A3RVDXHXWXI6K4  B00F8K9MZQ
# 26      4.0  A28DEENZR1ER2A  B00F8K9MZQ
# 27      5.0  A3TNXRZR8ESVU3  B00F8K9MZQ
# 28      5.0   A7NQJPXN1QBLH  B00F8K9MZQ
# 29      4.0   AJK49DENMS2BT  B00F8K9MZQ
# 30      5.0   A6FSYF9LXS7AE  B00F8K9MZQ
# 31      3.0   ADEZOPMPKK146  B00F8K9MZQ
# 32      5.0  A2QK6CWANYGXTB  B00F8K9MZQ
# 33      5.0  A2IX2PCXS5O2FK  B00F8K9MZQ
# 34      5.0  A3NMEF3MJ0A3PL  B00F8K9MZQ
# 35      1.0  A2AOW20EGSCAY2  B00F8K9MZQ
# 36      5.0  A1GGXJZOI5GEAQ  B00F8K9MZQ
# 37      5.0  A18FT4SOVZ4CCW  B00F8K9MZQ
# 38      4.0  A2TXR85WQLE32N  B00F8K9MZQ
# 39      5.0   AX1EFGUXGMSQG  B00F8K9MZQ
# 40      3.0  A2EZTM9WY5B5IL  B00F8K9MZQ
# 41      5.0  A1LG1DKUZXGJ6J  B00F8K9MZQ
# 42      5.0  A1IJOBQD8CY8K1  B00F8K9MZQ
# 43      5.0  A2F2Y0BJS7V49Y  B00F8K9MZQ
# 44      4.0  A16LE2XBKYYRJJ  B00F8K9MZQ
# 45      5.0  A3VHYQ0MSE35HJ  B00F8K9MZQ
# 46      4.0   AFIHZGX5DMIXS  B00F8K9MZQ
# 47      2.0  A1AIKETKYWVID9  B00F8K9MZQ
# 48      4.0  A1KRT1B3C08AHQ  B00F8K9MZQ
# 49      4.0  A2VZ43530IHTJU  B00F8K9MZQ
#
#                                            reviewText  \
# 0   [used, turbotax, since, first, came, find, exc...
# 1   [taxes, every, year, tedious, job, nt, turbota...
# 2                      [always, good, easy, accurate]
# 3                                         [satisfied]
# 4                             [filed, without, issue]
# 5   [use, turbo, tax, every, year, taxes, disappoi...
# 6                               [best, tax, software]
# 7                                              [good]
# 8                             [delivered, advertised]
# 9   [2013, version, used, turbotax, taxcut, years,...
# 10  [good, product, use, every, year, done, since,...
# 11  [using, turbotax, many, years, however, end, t...
# 12                          [way, taxes, used, years]
# 13  [easy, follow, use, taxes, simple, since, nt, ...
# 14  [longtime, turbotax, user, find, program, cont...
# 15    [easy, use, accurate, love, electronic, filing]
# 16                 [good, product, reasonable, price]
# 17  [easy, install, upgrade, performed, expected, ...
# 18  [used, turbotax, every, year, seems, like, for...
# 19  [using, turbo, tax, years, simple, easy, use, ...
# 20                                              [job]
# 21                                     [worked, well]
# 22                                    [tax, software]
# 23  [happy, happy, joy, joy, advertised, gets, fou...
# 24  [using, turbotax, deluxe, taxes, every, year, ...
# 25  [4, year, prepared, taxes, turbo, tax, makes, ...
# 26  [best, use, year, year, brings, forward, year,...
# 27  [use, turbo, tax, every, year, taxes, tax, cho...
# 28  [used, hrblock, turbotax, products, may, issue...
# 29  [government, pretty, intimidating, especially,...
# 30  [used, turbotax, 20, years, never, audited, wo...
# 31  [turbotax, deluxe, fed, efile, state, 2013, re...
# 32  [turbo, tax, 2013, worked, really, great, year...
# 33  [right, buffalo, bob, tax, time, remember, how...
# 34  [found, answered, questions, last, year, certa...
# 35  [first, filed, online, turbotaxcom, previous, ...
# 36  [used, turbo, tax, last, four, years, problems...
# 37  [use, every, year, amazon, best, price, turbo,...
# 38  [turbotax, deluxe, edition, tax, year, 2013, o...
# 39  [used, tt, since, sold, developers, working, n...
# 40  [user, friendly, previous, years, wait, 4, day...
# 41  [though, refund, shrunk, quite, bit, year, not...
# 42  [used, turbotax, software, physical, disc, man...
# 43                                        [described]
# 44  [edition, turbotax, lacked, several, help, scr...
# 45  [always, use, turbotax, refunds, filed, taxes,...
# 46  [using, turbo, tax, 5, years, seems, liek, one...
# 47  [disappointed, turbo, tax, 2013, tax, year, en...
# 48  [problems, software, installing, updating, tax...
# 49  [turbotax, user, dozen, years, found, adequate...
#
#                                               summary  sentiment  \
# 0                                    [excellent, buy]   0.420833
# 1   [solid, reliable, tax, software, program, used...   0.192667
# 2                                       [five, stars]   0.511111
# 3                                       [four, stars]   0.500000
# 4                                            [worked]   0.000000
# 5                  [turbo, tax, notsodeluxe, edition]   0.150000
# 6                                         [tax, time]   1.000000
# 7                                       [five, stars]   0.700000
# 8                                       [four, stars]   0.000000
# 9                        [wash, turbotax, vs, taxcut]   0.366667
# 10                                      [five, stars]   0.700000
# 11       [last, good, product, turbotax, 2014, sucks]   0.200000
# 12                             [great, tax, software]   0.000000
# 13                                    [good, product]   0.288889
# 14                    [another, good, year, turbotax]   0.400000
# 15                                      [five, stars]   0.444444
# 16                                      [four, stars]   0.450000
# 17                                      [five, stars]   0.166667
# 18                                      [used, years]   0.275000
# 19                                         [tax, man]   0.288889
# 20                                        [tax, time]   0.000000
# 21                                      [five, stars]   0.000000
# 22                                      [four, stars]   0.000000
# 23                           [happy, happy, joy, joy]   0.383333
# 24                               [could, nt, without]   0.306667
# 25                                        [tax, time]   0.041667
# 26                                  [used, yearsgood]   0.566667
# 27             [turbo, tax, definitive, tax, program]   0.333333
# 28                                       [complaints]   0.176190
# 29                       [saves, lot, effort, pricey]   0.076667
# 30                 [turbotax, deluxe, great, program]  -0.033333
# 31                               [good, tax, program]   0.650000
# 32                                   [turbotax, 2013]   0.616667
# 33                                  [hey, kids, time]   0.311012
# 34            [works, fine, even, better, last, year]   0.198214
# 35                                 [highway, robbery]  -0.083095
# 36                                 [repeat, customer]   0.300000
# 37                                  [great, software]   0.476667
# 38                                        [get, done]  -0.048214
# 39                 [excellent, product, better, year]   0.158333
# 40                                            [great]   0.031667
# 41                                       [good, ever]   0.080000
# 42                                  [turbotax, rules]   0.187968
# 43                                      [five, stars]   0.000000
# 44                   [review, turbotax, deluxe, 2013]  -0.012500
# 45                  [quick, ship, quick, tax, refund]   0.000000
# 46                             [5, years, turbo, tax]   0.062500
# 47                                     [disappointed]  -0.104545
# 48        [bonus, amazon, refund, bit, disconcerting]   0.195833
# 49  [comprehensive, taxfiling, software, suitable,...   0.297619
#
#     sentiment_category
# 0                    1
# 1                    0
# 2                    1
# 3                    1
# 4                    0
# 5                    0
# 6                    1
# 7                    1
# 8                    0
# 9                    1
# 10                   1
# 11                   0
# 12                   0
# 13                   0
# 14                   1
# 15                   1
# 16                   1
# 17                   0
# 18                   0
# 19                   0
# 20                   0
# 21                   0
# 22                   0
# 23                   1
# 24                   1
# 25                   0
# 26                   1
# 27                   1
# 28                   0
# 29                   0
# 30                   0
# 31                   1
# 32                   1
# 33                   1
# 34                   0
# 35                   0
# 36                   1
# 37                   1
# 38                   0
# 39                   0
# 40                   0
# 41                   0
# 42                   0
# 43                   0
# 44                   0
# 45                   0
# 46                   0
# 47                  -1
# 48                   0
# 49                   0

# %%
df4['sentiment_category'].value_counts()
# Out:
# sentiment_category
#  0    45
#  1    28
# -1     1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
sentiment_categories = [114, 108, 10]
categories = ['Positive', 'Neutral', 'Negative']

#bar plot
plt.figure(figsize=(8, 6))
plt.bar(categories, sentiment_categories, color=['green', 'blue', 'red'])
plt.xlabel('Sentiment Category')
plt.ylabel('Frequency')
plt.title('Distribution of Sentiment Categories')
plt.show()

# %%
from nltk import pos_tag, word_tokenize
from collections import Counter
from wordcloud import WordCloud

positive_reviews = df4[df4['sentiment_category'] == 1]['reviewText']
feature_words = [word for review in positive_reviews for word in review]
feature_word_freq = Counter(feature_words)
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(feature_word_freq)
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Frequent Features in Positive Reviews')
plt.show()

top_features = feature_word_freq.most_common(10)  # Top 10 features
feature_names, frequencies = zip(*top_features)

plt.figure(figsize=(10, 6))
plt.barh(feature_names, frequencies, color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('Feature')
plt.title('Top Features in Positive Reviews')
plt.gca().invert_yaxis()
plt.show()

# %%
def get_sentiment(text):
    analysis = TextBlob(str(text))
    return analysis.sentiment.polarity
df4['sentiment2'] = df4['summary'].apply(get_sentiment)
print(df4[['summary', 'sentiment2']].head(10))
# Out:
#                                              summary  sentiment2
# 0                                   [excellent, buy]        1.00
# 1  [solid, reliable, tax, software, program, used...        0.25
# 2                                      [five, stars]        0.00
# 3                                      [four, stars]        0.00
# 4                                           [worked]        0.00
# 5                 [turbo, tax, notsodeluxe, edition]        0.00
# 6                                        [tax, time]        0.00
# 7                                      [five, stars]        0.00
# 8                                      [four, stars]        0.00
# 9                       [wash, turbotax, vs, taxcut]        0.00

# %%
def get_sentiment_category(score):
    if score > 0.5: 
        return 1  # Positive sentiment
    elif score < -0.1:
        return -1  # Negative sentiment
    else:
        return 0  # Neutral sentiment or no strong sentiment

df4['sentiment2_category'] = df4['sentiment2'].apply(get_sentiment_category)
print(df4[['summary', 'sentiment2_category']].head(10))
# Out:
#                                              summary  sentiment2_category
# 0                                   [excellent, buy]                    1
# 1  [solid, reliable, tax, software, program, used...                    0
# 2                                      [five, stars]                    0
# 3                                      [four, stars]                    0
# 4                                           [worked]                    0
# 5                 [turbo, tax, notsodeluxe, edition]                    0
# 6                                        [tax, time]                    0
# 7                                      [five, stars]                    0
# 8                                      [four, stars]                    0
# 9                       [wash, turbotax, vs, taxcut]                    0

# %%
from nltk import pos_tag, word_tokenize
from collections import Counter
from wordcloud import WordCloud
positive_reviews = df4[df4['sentiment2_category'] == 1]['summary']
feature_words = [word for review in positive_reviews for word in review]
feature_word_freq = Counter(feature_words)
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(feature_word_freq)
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Frequent Features in Positive Reviews')
plt.show()

top_features = feature_word_freq.most_common(10)  # Top 10 features
feature_names, frequencies = zip(*top_features)

plt.figure(figsize=(10, 6))
plt.barh(feature_names, frequencies, color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('Feature')
plt.title('Top Features in Positive Reviews')
plt.gca().invert_yaxis()
plt.show()

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\vinut\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#Aspect based sentiment analysis
from nltk import pos_tag
tagged_feature = pos_tag(feature_words)
aspect_keyword = [word for word, pos in tagged_feature if pos in ['NN', 'NNS', 'JJ']]
print(aspect_keyword)
# Out:
# ['excellent', 'great', 'tax', 'software', 'good', 'product', 'good', 'year', 'turbotax', 'happy', 'happy', 'joy', 'joy', 'turbotax', 'deluxe', 'great', 'program', 'good', 'tax', 'program', 'great', 'software', 'excellent', 'product', 'year', 'great', 'good', 'turbotax', 'deluxe', 'updated', 'glitch', 'great', 'software', 'years', 'good', 'recommendations', 'likely', 'perfect', 'turbotax', 'deluxe', 'nys', 'tax', 'preparation', 'software', 'superior', 'way', 'turbotax', 'deluxe', 'fedstateefile', 'turbotax', 'deluxe', 'pc', 'download']

# %%
df_aspect = pd.read_csv('C:\\Users\\vinut\\Desktop\\DataMining Project\\B00F8K9MZQ_data.csv')

df_aspect.head(5)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      5.0      True   12 2, 2013  A3H1L8J408EMXK  B00F8K9MZQ
# 1      5.0      True  11 26, 2013  A1X1CEGHTHMBL1  B00F8K9MZQ
# 2      5.0      True  04 13, 2016  A2SQZL4FSRTKA6  B00F8K9MZQ
# 3      4.0      True   12 2, 2015  A1DPOEBIUY9IVI  B00F8K9MZQ
# 4      5.0      True  07 17, 2015  A2ZFQ9RT9Y9NQN  B00F8K9MZQ
#
#                            style  reviewerName  \
# 0  {'Platform:': ' PC/Mac Disc'}  Great Poobah
# 1  {'Platform:': ' PC/Mac Disc'}         JJCEO
# 2  {'Platform:': ' PC/Mac Disc'}     Roy Batty
# 3  {'Platform:': ' PC/Mac Disc'}        Vishwa
# 4  {'Platform:': ' PC/Mac Disc'}       rigilsp
#
#                                           reviewText  \
# 0  I've used Turbotax since it first came out and...
# 1  I do our taxes every year and it is a tedious ...
# 2                   Always good, easy, and accurate.
# 3                                          satisfied
# 4                               Filed without issue.
#
#                                              summary  unixReviewTime   vote  \
# 0                                   An excellent buy      1385942400    4.0
# 1  A solid and reliable tax software program that...      1385424000  127.0
# 2                                         Five Stars      1460505600    NaN
# 3                                         Four Stars      1449014400    NaN
# 4                                          It worked      1437091200    NaN
#
#    image
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
def extract_aspects(text):
    doc = nlp(text)
    aspects = []
    for token in doc:
        if token.pos_ == "NOUN":    #extracts noun
            aspects.append(token.text)
    return aspects


review_text = "All the reviews are not for the product listed. Amazon needs to straighten this mess out"
aspects = extract_aspects(review_text)
print("Aspects:",aspects)
# Out:
# Aspects: ['reviews', 'product', 'mess']

# %%
df_review = df_aspect['reviewText']

def extract_aspects(text):
    doc = nlp(text)
    aspects = [token.text for token in doc if token.pos_ == "NOUN"]
    return aspects

# applying the extract_aspects function to the 'reviewText' column
df_aspects = df_review.apply(extract_aspects)
df_review = pd.DataFrame(df_review)
df_review['aspects'] = df_aspects
df_review = df_review.rename(columns={'reviewText': 'reviews'})
print(df_review)
# Out:
#                                               reviews  \
# 0   I've used Turbotax since it first came out and...
# 1   I do our taxes every year and it is a tedious ...
# 2                    Always good, easy, and accurate.
# 3                                           satisfied
# 4                                Filed without issue.
# ..                                                ...
# 69  I love turbo Tax.  I have used it for many yea...
# 70  TTax2013 is solid and fast as were the prior t...
# 71  Do NOT buy this product!  You can go to the Tu...
# 72                                            Perfecr
# 73                               Received as expected
#
#                                               aspects
# 0   [buy, people, accountant, bunch, money, step, ...
# 1   [taxes, year, job, year, version, years, softw...
# 2                                                  []
# 3                                                  []
# 4                                             [issue]
# ..                                                ...
# 69  [turbo, years, needs, questions, refund, tax, ...
# 70  [tax, year, versions, price, sellers, Intuit, ...
# 71  [product, site, Errors, kind, problems, people...
# 72                                          [Perfecr]
# 73                                                 []
#
# [74 rows x 2 columns]

# %%
from collections import Counter
all_aspects = [aspect for sublist in df_review['aspects'] for aspect in sublist]
aspect_counts = Counter(all_aspects)
top_aspects = aspect_counts.most_common(5)

# Print the top aspects and their counts
print("Top Aspects:")
for aspect, count in top_aspects:
    print(f"{aspect}: {count} mentions")
# Out:
# Top Aspects:
# tax: 66 mentions
# year: 63 mentions
# years: 43 mentions
# taxes: 41 mentions
# software: 32 mentions

# %%
aspects, counts = zip(*top_aspects)

# Plotting the graph
plt.figure(figsize=(10, 6))
plt.bar(aspects, counts, color='skyblue')
plt.xlabel('Aspects')
plt.ylabel('Frequency')
plt.title('Top Aspects or Features')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
aspects, counts = zip(*top_aspects)

#pie chart
plt.figure(figsize=(8, 8))
plt.pie(counts, labels=aspects, autopct='%1.1f%%', startangle=140)
plt.title('Top Aspects Distribution')
plt.axis('equal')  
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings("ignore")

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_review['reviews'], df4['sentiment_category'], test_size=0.3, random_state=42)
model = make_pipeline(TfidfVectorizer(), SVC(kernel='linear', random_state=42))
#model = make_pipeline(TfidfVectorizer(), RandomForestClassifier(n_estimators=100, random_state=42))
model.fit(X_train, y_train)   #Fit the model
predictions = model.predict(X_test) # Make predictions on the test set

#find accuracy
accuracy = accuracy_score(y_test, predictions)
print("Test Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, predictions))

# For new reviews,predict:
new_reviews = [
    "Very disappointed with the performance. Would not recommend.",
    "Amazing product",
    "Bad","Great Product","Good good"
]
new_predictions = model.predict(new_reviews)
print("\nPredicted Sentiments for New Reviews:", new_predictions)
# Out:
# Test Accuracy: 0.7391304347826086
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.94      0.83        16
#            1       0.67      0.29      0.40         7
#
#     accuracy                           0.74        23
#    macro avg       0.71      0.61      0.62        23
# weighted avg       0.72      0.74      0.70        23
#
#
# Predicted Sentiments for New Reviews: [0 1 0 1 1]

# %%
sentiment_mapping = {
    0: 'Negative',
    1: 'Positive'
}
predicted_sentiments = [sentiment_mapping[label] for label in new_predictions]
colors = ['red' if pred == 'Negative' else 'green' for pred in predicted_sentiments]

# Plotting sentiment predictions for new reviews
plt.figure(figsize=(10, 6))
plt.barh(range(len(new_reviews)), [1 if pred == 'Positive' else -1 for pred in predicted_sentiments], color=colors)
plt.yticks(range(len(new_reviews)), new_reviews)
plt.xlabel('Sentiment')
plt.title('Sentiment Predictions for New Reviews')
plt.gca().invert_yaxis()  # Invert y-axis to display the most recent review at the top
plt.show()

# %%
# top aspects and associated sentiment words with their synonyms
aspect_sentiments = {
    'product': ['excellent', 'good', 'great', 'bad', 'poor', 'disappointing'],
    'router': ['fast', 'reliable', 'slow', 'unreliable'],
    'switch': ['efficient', 'effective', 'inefficient', 'ineffective'],
    'port': ['compatible', 'incompatible', 'functional', 'non-functional'],
    'device': ['sophisticated', 'basic', 'advanced', 'outdated']
}

# rule-based sentiment analysis approach:
def rule_based_sentiment_analysis(review):
    sentiment_scores = {}
    for aspect, sentiment_words in aspect_sentiments.items():
        aspect_sentiment = 'neutral'
        for word in sentiment_words:
            if isinstance(review, str) and isinstance(word, str) and word in review.lower():
                aspect_sentiment = 'positive'
                break
        sentiment_scores[aspect] = aspect_sentiment
    
    return sentiment_scores
top_aspects = ['tax', 'year', 'years', 'taxes', 'software']
for aspect in top_aspects:
    reviews_with_aspect = df_review[df_review['aspects'].apply(lambda x: aspect in x)]['reviews']
    aspect_sentiments = reviews_with_aspect.apply(rule_based_sentiment_analysis)
    for idx, sentiments in aspect_sentiments.items():
        print(f"Review: {idx}")
        print("Sentiments:", sentiments)
    print()
# Out:
# Review: 0
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 1
# Sentiments: {'product': 'positive', 'router': 'positive', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 6
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 11
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 22
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 25
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 28
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 29
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 30
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 31
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 33
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 36
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 38
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'positive'}
# Review: 39
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 41
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 42
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 47
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 50
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 53
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 56
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 57
# Sentiments: {'product': 'neutral', 'router': 'positive', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 60
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 61
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'positive', 'port': 'neutral', 'device': 'neutral'}
# Review: 62
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'positive', 'device': 'neutral'}
# Review: 65
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 68
# Sentiments: {'product': 'neutral', 'router': 'positive', 'switch': 'neutral', 'port': 'neutral', 'device': 'positive'}
# Review: 69
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 70
# Sentiments: {'product': 'neutral', 'router': 'positive', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
#
# Review: 1
# Sentiments: {0: 'positive', 1: 'positive', 6: 'positive', 11: 'positive', 22: 'positive', 25: 'positive', 28: 'positive', 29: 'positive', 30: 'positive', 31: 'positive', 33: 'positive', 36: 'positive', 38: 'positive', 39: 'positive', 41: 'positive', 42: 'positive', 47: 'positive', 50: 'positive', 53: 'positive', 56: 'positive', 57: 'positive', 60: 'positive', 61: 'positive', 62: 'positive', 65: 'positive', 68: 'positive', 69: 'positive', 70: 'positive'}
# Review: 5
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 10
# Sentiments: {0: 'positive', 1: 'positive', 6: 'positive', 11: 'positive', 22: 'positive', 25: 'positive', 28: 'positive', 29: 'positive', 30: 'positive', 31: 'positive', 33: 'positive', 36: 'positive', 38: 'positive', 39: 'positive', 41: 'positive', 42: 'positive', 47: 'positive', 50: 'positive', 53: 'positive', 56: 'positive', 57: 'positive', 60: 'positive', 61: 'positive', 62: 'positive', 65: 'positive', 68: 'positive', 69: 'positive', 70: 'positive'}
# Review: 11
# Sentiments: {0: 'positive', 1: 'positive', 6: 'positive', 11: 'positive', 22: 'positive', 25: 'positive', 28: 'positive', 29: 'positive', 30: 'positive', 31: 'positive', 33: 'positive', 36: 'positive', 38: 'positive', 39: 'positive', 41: 'positive', 42: 'positive', 47: 'positive', 50: 'positive', 53: 'positive', 56: 'positive', 57: 'positive', 60: 'positive', 61: 'positive', 62: 'positive', 65: 'positive', 68: 'positive', 69: 'positive', 70: 'positive'}
# Review: 18
# Sentiments: {0: 'positive', 1: 'positive', 6: 'positive', 11: 'positive', 22: 'positive', 25: 'positive', 28: 'positive', 29: 'positive', 30: 'positive', 31: 'positive', 33: 'positive', 36: 'positive', 38: 'positive', 39: 'positive', 41: 'positive', 42: 'positive', 47: 'positive', 50: 'positive', 53: 'positive', 56: 'positive', 57: 'positive', 60: 'positive', 61: 'positive', 62: 'positive', 65: 'positive', 68: 'positive', 69: 'positive', 70: 'positive'}
# Review: 24
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 25
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 26
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 27
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 28
# Sentiments: {0: 'positive', 1: 'positive', 6: 'positive', 11: 'positive', 22: 'positive', 25: 'positive', 28: 'positive', 29: 'positive', 30: 'positive', 31: 'positive', 33: 'positive', 36: 'positive', 38: 'positive', 39: 'positive', 41: 'positive', 42: 'positive', 47: 'positive', 50: 'positive', 53: 'positive', 56: 'positive', 57: 'positive', 60: 'positive', 61: 'positive', 62: 'positive', 65: 'positive', 68: 'positive', 69: 'positive', 70: 'positive'}
# Review: 32
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 34
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 36
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 37
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 38
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 39
# Sentiments: {0: 'positive', 1: 'positive', 6: 'positive', 11: 'positive', 22: 'positive', 25: 'positive', 28: 'positive', 29: 'positive', 30: 'positive', 31: 'positive', 33: 'positive', 36: 'positive', 38: 'positive', 39: 'positive', 41: 'positive', 42: 'positive', 47: 'positive', 50: 'positive', 53: 'positive', 56: 'positive', 57: 'positive', 60: 'positive', 61: 'positive', 62: 'positive', 65: 'positive', 68: 'positive', 69: 'positive', 70: 'positive'}
# Review: 41
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 42
# Sentiments: {0: 'positive', 1: 'positive', 6: 'positive', 11: 'positive', 22: 'positive', 25: 'positive', 28: 'positive', 29: 'positive', 30: 'positive', 31: 'positive', 33: 'positive', 36: 'positive', 38: 'positive', 39: 'positive', 41: 'positive', 42: 'positive', 47: 'positive', 50: 'positive', 53: 'positive', 56: 'positive', 57: 'positive', 60: 'positive', 61: 'positive', 62: 'positive', 65: 'positive', 68: 'positive', 69: 'positive', 70: 'positive'}
# Review: 47
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 48
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 49
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 51
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 52
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 54
# Sentiments: {0: 'positive', 1: 'positive', 6: 'positive', 11: 'positive', 22: 'positive', 25: 'positive', 28: 'positive', 29: 'positive', 30: 'positive', 31: 'positive', 33: 'positive', 36: 'positive', 38: 'positive', 39: 'positive', 41: 'positive', 42: 'positive', 47: 'positive', 50: 'positive', 53: 'positive', 56: 'positive', 57: 'positive', 60: 'positive', 61: 'positive', 62: 'positive', 65: 'positive', 68: 'positive', 69: 'positive', 70: 'positive'}
# Review: 56
# Sentiments: {0: 'positive', 1: 'positive', 6: 'positive', 11: 'positive', 22: 'positive', 25: 'positive', 28: 'positive', 29: 'positive', 30: 'positive', 31: 'positive', 33: 'positive', 36: 'positive', 38: 'positive', 39: 'positive', 41: 'positive', 42: 'positive', 47: 'positive', 50: 'positive', 53: 'positive', 56: 'positive', 57: 'positive', 60: 'positive', 61: 'positive', 62: 'positive', 65: 'positive', 68: 'positive', 69: 'positive', 70: 'positive'}
# Review: 57
# Sentiments: {0: 'positive', 1: 'positive', 6: 'positive', 11: 'positive', 22: 'positive', 25: 'positive', 28: 'positive', 29: 'positive', 30: 'positive', 31: 'positive', 33: 'positive', 36: 'positive', 38: 'positive', 39: 'positive', 41: 'positive', 42: 'positive', 47: 'positive', 50: 'positive', 53: 'positive', 56: 'positive', 57: 'positive', 60: 'positive', 61: 'positive', 62: 'positive', 65: 'positive', 68: 'positive', 69: 'positive', 70: 'positive'}
# Review: 58
# Sentiments: {0: 'positive', 1: 'positive', 6: 'positive', 11: 'positive', 22: 'positive', 25: 'positive', 28: 'positive', 29: 'positive', 30: 'positive', 31: 'positive', 33: 'positive', 36: 'positive', 38: 'positive', 39: 'positive', 41: 'positive', 42: 'positive', 47: 'positive', 50: 'positive', 53: 'positive', 56: 'positive', 57: 'positive', 60: 'positive', 61: 'positive', 62: 'positive', 65: 'positive', 68: 'positive', 69: 'positive', 70: 'positive'}
# Review: 62
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 63
# Sentiments: {0: 'positive', 1: 'positive', 6: 'positive', 11: 'positive', 22: 'positive', 25: 'positive', 28: 'positive', 29: 'positive', 30: 'positive', 31: 'positive', 33: 'positive', 36: 'positive', 38: 'positive', 39: 'positive', 41: 'positive', 42: 'positive', 47: 'positive', 50: 'positive', 53: 'positive', 56: 'positive', 57: 'positive', 60: 'positive', 61: 'positive', 62: 'positive', 65: 'positive', 68: 'positive', 69: 'positive', 70: 'positive'}
# Review: 67
# Sentiments: {0: 'positive', 1: 'positive', 6: 'positive', 11: 'positive', 22: 'positive', 25: 'positive', 28: 'positive', 29: 'positive', 30: 'positive', 31: 'positive', 33: 'positive', 36: 'positive', 38: 'positive', 39: 'positive', 41: 'positive', 42: 'positive', 47: 'positive', 50: 'positive', 53: 'positive', 56: 'positive', 57: 'positive', 60: 'positive', 61: 'positive', 62: 'positive', 65: 'positive', 68: 'positive', 69: 'positive', 70: 'positive'}
# Review: 68
# Sentiments: {0: 'positive', 1: 'positive', 6: 'positive', 11: 'positive', 22: 'positive', 25: 'positive', 28: 'positive', 29: 'positive', 30: 'positive', 31: 'positive', 33: 'positive', 36: 'positive', 38: 'positive', 39: 'positive', 41: 'positive', 42: 'positive', 47: 'positive', 50: 'positive', 53: 'positive', 56: 'positive', 57: 'positive', 60: 'positive', 61: 'positive', 62: 'positive', 65: 'positive', 68: 'positive', 69: 'positive', 70: 'positive'}
# Review: 70
# Sentiments: {0: 'neutral', 1: 'neutral', 6: 'neutral', 11: 'neutral', 22: 'neutral', 25: 'neutral', 28: 'neutral', 29: 'neutral', 30: 'neutral', 31: 'neutral', 33: 'neutral', 36: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 50: 'neutral', 53: 'neutral', 56: 'neutral', 57: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 65: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
#
# Review: 1
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 9
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 11
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 12
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 18
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 19
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 25
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 26
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 30
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 34
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 35
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 36
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 40
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 41
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 42
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 46
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 49
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 50
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 53
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 54
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 55
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 56
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 58
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 60
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 61
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 62
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 63
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 64
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 65
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 66
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 68
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 69
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
# Review: 70
# Sentiments: {1: 'neutral', 5: 'neutral', 10: 'neutral', 11: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 26: 'neutral', 27: 'neutral', 28: 'neutral', 32: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 39: 'neutral', 41: 'neutral', 42: 'neutral', 47: 'neutral', 48: 'neutral', 49: 'neutral', 51: 'neutral', 52: 'neutral', 54: 'neutral', 56: 'neutral', 57: 'neutral', 58: 'neutral', 62: 'neutral', 63: 'neutral', 67: 'neutral', 68: 'neutral', 70: 'neutral'}
#
# Review: 1
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 5
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 12
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 13
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 18
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 24
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 25
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 27
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 33
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 34
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 36
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 37
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 38
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 41
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 44
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 45
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 48
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 52
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 55
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 56
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 60
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 61
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 62
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 64
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 67
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
# Review: 68
# Sentiments: {1: 'neutral', 9: 'neutral', 11: 'neutral', 12: 'neutral', 18: 'neutral', 19: 'neutral', 25: 'neutral', 26: 'neutral', 30: 'neutral', 34: 'neutral', 35: 'neutral', 36: 'neutral', 40: 'neutral', 41: 'neutral', 42: 'neutral', 46: 'neutral', 49: 'neutral', 50: 'neutral', 53: 'neutral', 54: 'neutral', 55: 'neutral', 56: 'neutral', 58: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 63: 'neutral', 64: 'neutral', 65: 'neutral', 66: 'neutral', 68: 'neutral', 69: 'neutral', 70: 'neutral'}
#
# Review: 1
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 6
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 18
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 22
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 30
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 34
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 35
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 37
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 41
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 42
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 46
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 47
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 48
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 49
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 53
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 54
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 56
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 59
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 61
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 62
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 65
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 67
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
# Review: 68
# Sentiments: {1: 'neutral', 5: 'neutral', 12: 'neutral', 13: 'neutral', 18: 'neutral', 24: 'neutral', 25: 'neutral', 27: 'neutral', 33: 'neutral', 34: 'neutral', 36: 'neutral', 37: 'neutral', 38: 'neutral', 41: 'neutral', 44: 'neutral', 45: 'neutral', 48: 'neutral', 52: 'neutral', 55: 'neutral', 56: 'neutral', 60: 'neutral', 61: 'neutral', 62: 'neutral', 64: 'neutral', 67: 'neutral', 68: 'neutral'}
