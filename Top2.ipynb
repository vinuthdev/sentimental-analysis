# %%
import pandas as pd
import json

with open('C:\\Users\\vinut\\Desktop\\DataMining Project\\Software_5.json') as f:
    data = [json.loads(line) for line in f]
df = pd.DataFrame(data)
df.to_csv('output.csv', index=False)

# %%
df = pd.read_csv('output.csv')
df_sorted = df.sort_values(by='asin')
asin_counts = df_sorted['asin'].value_counts()
unique = asin_counts.index.tolist()
count = asin_counts.values.tolist()
unique_asin_data = pd.DataFrame({'asin': unique, 'count': count})
print("Unique values and their counts:")
print(unique_asin_data)

sum_hundred = asin_counts.head(100).sum()
print("Sum of the first 100 counts:", sum_hundred)
# Out:
# Unique values and their counts:
#            asin  count
# 0    B0000AZJY6    452
# 1    B000EORV8Q    232
# 2    B0001FS9NE    230
# 3    B000050ZRE    230
# 4    B00EZPXYP4     98
# ..          ...    ...
# 797  B0011SFXCK      1
# 798  B00149YSUY      1
# 799  B0012KW3KM      1
# 800  B00132DENO      1
# 801  B0015CA9VW      1
#
# [802 rows x 2 columns]
# Sum of the first 100 counts: 4938

# %%
# filtered_data = df_sorted[df_sorted['asin'] == 'B000EORV8Q']
# file_name = f'B0000AZJY6_data.csv'
# filtered_data.to_csv(file_name, index=False)
# print(f"Data for 'B0000AZJY6' saved in {file_name}")

import pandas as pd

# Assuming your data is in a DataFrame named 'df'
# Replace 'your_dataset.csv' with your actual dataset filename
df = pd.read_csv('output.csv')

# Filter data for 'B0000AZJY6'
filtered_data = df[df['asin'] == 'B000EORV8Q']

# Save filtered data to a new file
filtered_data.to_csv('B000EORV8Q_data.csv', index=False)

# %%
df2 = pd.read_csv('C:\\Users\\vinut\\Desktop\\DataMining Project\\B000EORV8Q_data.csv')

df2.head(5)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  style  \
# 0      1.0     False  05 15, 2018  A2HL609RR13WNZ  B000EORV8Q    NaN
# 1      1.0      True  05 14, 2018  A14HDK1OLFYMVM  B000EORV8Q    NaN
# 2      1.0     False  05 13, 2018  A3P2DW4YDYK88C  B000EORV8Q    NaN
# 3      5.0      True   04 9, 2018  A2N4Y0OQ8RP88Y  B000EORV8Q    NaN
# 4      5.0      True  03 28, 2018  A24G9X47GNVI02  B000EORV8Q    NaN
#
#              reviewerName                                         reviewText  \
# 0  George Leroy Tirebiter  All the reviews are not for the product listed...
# 1                      AL  So far, I am not impressed. It did arrive quic...
# 2                W. Racca  I looked at purchasing this Router.  However, ...
# 3              Pat Senter  I thought this to be very inexpensive for all ...
# 4                  Freddy  very good computer the intel Dual Core i3-2120...
#
#                                              summary  unixReviewTime  vote  \
# 0                                Doesn't Make Sense.      1526342400   NaN
# 1              Does Not Work. I Feel I've Been "Had"      1526256000   NaN
# 2  I looked at purchasing this Router. However, o...      1526169600   NaN
# 3  Great for the you boys for their computer cent...      1523232000   NaN
# 4   very good computer the intel Dual Core i3-2120 3      1522195200   NaN
#
#    image
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
print(df2.columns)
# Out:
# Index(['overall', 'verified', 'reviewTime', 'reviewerID', 'asin', 'style',
#        'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'vote',
#        'image'],
#       dtype='object')

# %%
columns_to_remove = ['image', 'style']
df2 = df2.drop(columns=columns_to_remove)
df2.head(5)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      1.0     False  05 15, 2018  A2HL609RR13WNZ  B000EORV8Q
# 1      1.0      True  05 14, 2018  A14HDK1OLFYMVM  B000EORV8Q
# 2      1.0     False  05 13, 2018  A3P2DW4YDYK88C  B000EORV8Q
# 3      5.0      True   04 9, 2018  A2N4Y0OQ8RP88Y  B000EORV8Q
# 4      5.0      True  03 28, 2018  A24G9X47GNVI02  B000EORV8Q
#
#              reviewerName                                         reviewText  \
# 0  George Leroy Tirebiter  All the reviews are not for the product listed...
# 1                      AL  So far, I am not impressed. It did arrive quic...
# 2                W. Racca  I looked at purchasing this Router.  However, ...
# 3              Pat Senter  I thought this to be very inexpensive for all ...
# 4                  Freddy  very good computer the intel Dual Core i3-2120...
#
#                                              summary  unixReviewTime  vote
# 0                                Doesn't Make Sense.      1526342400   NaN
# 1              Does Not Work. I Feel I've Been "Had"      1526256000   NaN
# 2  I looked at purchasing this Router. However, o...      1526169600   NaN
# 3  Great for the you boys for their computer cent...      1523232000   NaN
# 4   very good computer the intel Dual Core i3-2120 3      1522195200   NaN

# %%
null = df2.isnull().sum()
print(null)
# Out:
# overall             0
# verified            0
# reviewTime          0
# reviewerID          0
# asin                0
# reviewerName        0
# reviewText          0
# summary             1
# unixReviewTime      0
# vote              232
# dtype: int64

# %%
df2['summary'].fillna('No summary', inplace=True)
df2['vote'].fillna(0, inplace=True)
null2 = df2.isnull().sum()
print(null2)
# Out:
# overall           0
# verified          0
# reviewTime        0
# reviewerID        0
# asin              0
# reviewerName      0
# reviewText        0
# summary           0
# unixReviewTime    0
# vote              0
# dtype: int64

# %%
count = df2['verified'].value_counts()
print(count)
# Out:
# verified
# True     175
# False     57
# Name: count, dtype: int64

# %%
df2
# Out:
#      overall  verified   reviewTime      reviewerID        asin  \
# 0        1.0     False  05 15, 2018  A2HL609RR13WNZ  B000EORV8Q
# 1        1.0      True  05 14, 2018  A14HDK1OLFYMVM  B000EORV8Q
# 2        1.0     False  05 13, 2018  A3P2DW4YDYK88C  B000EORV8Q
# 3        5.0      True   04 9, 2018  A2N4Y0OQ8RP88Y  B000EORV8Q
# 4        5.0      True  03 28, 2018  A24G9X47GNVI02  B000EORV8Q
# ..       ...       ...          ...             ...         ...
# 227      5.0      True  09 26, 2003   AFFTVSSV0D5A1  B000EORV8Q
# 228      5.0     False   11 8, 2002  A3TLPNECI4DG3N  B000EORV8Q
# 229      5.0     False  05 25, 2002  A1MJWOYNJSZPPJ  B000EORV8Q
# 230      1.0      True  05 17, 2018  A2RV54OXBGRD2Z  B000EORV8Q
# 231      5.0     False  05 16, 2018  A3PWOYJPO4CT93  B000EORV8Q
#
#                reviewerName  \
# 0    George Leroy Tirebiter
# 1                        AL
# 2                  W. Racca
# 3                Pat Senter
# 4                    Freddy
# ..                      ...
# 227                       D
# 228         Carl Fongheiser
# 229                   James
# 230             minwei chen
# 231              Camille M.
#
#                                             reviewText  \
# 0    All the reviews are not for the product listed...
# 1    So far, I am not impressed. It did arrive quic...
# 2    I looked at purchasing this Router.  However, ...
# 3    I thought this to be very inexpensive for all ...
# 4    very good computer the intel Dual Core i3-2120...
# ..                                                 ...
# 227  I am very satisfied with the purchase of this ...
# 228  Need to network computers on different floors?...
# 229  You can't go wrong with this device.  It's the...
# 230  The review that has 5 stars\nI really wonder t...
# 231  perfect device. the only thing that would Make...
#
#                                                summary  unixReviewTime  vote
# 0                                  Doesn't Make Sense.      1526342400   0.0
# 1                Does Not Work. I Feel I've Been "Had"      1526256000   0.0
# 2    I looked at purchasing this Router. However, o...      1526169600   0.0
# 3    Great for the you boys for their computer cent...      1523232000   0.0
# 4     very good computer the intel Dual Core i3-2120 3      1522195200   0.0
# ..                                                 ...             ...   ...
# 227  Good product, which is very easy to setup and use      1064534400   0.0
# 228                Easy to set up, works like a dream!      1036713600   0.0
# 229                                    Solid performer      1022284800   0.0
# 230  ... doesn't stay connected the whole time I wo...      1526515200   0.0
# 231  perfect device. the only thing that would Make...      1526428800   0.0
#
# [232 rows x 10 columns]

# %%
columns_to_remove = ['unixReviewTime', 'reviewTime','reviewerName','verified','vote']
df2 = df2.drop(columns=columns_to_remove)
df2.head(5)
# Out:
#    overall      reviewerID        asin  \
# 0      1.0  A2HL609RR13WNZ  B000EORV8Q
# 1      1.0  A14HDK1OLFYMVM  B000EORV8Q
# 2      1.0  A3P2DW4YDYK88C  B000EORV8Q
# 3      5.0  A2N4Y0OQ8RP88Y  B000EORV8Q
# 4      5.0  A24G9X47GNVI02  B000EORV8Q
#
#                                           reviewText  \
# 0  All the reviews are not for the product listed...
# 1  So far, I am not impressed. It did arrive quic...
# 2  I looked at purchasing this Router.  However, ...
# 3  I thought this to be very inexpensive for all ...
# 4  very good computer the intel Dual Core i3-2120...
#
#                                              summary
# 0                                Doesn't Make Sense.
# 1              Does Not Work. I Feel I've Been "Had"
# 2  I looked at purchasing this Router. However, o...
# 3  Great for the you boys for their computer cent...
# 4   very good computer the intel Dual Core i3-2120 3

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
def tokenize_text(text):
    tokens = word_tokenize(str(text))  # Tokenize the text
    return tokens
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vinut\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Tokenizing 'reviewText' column
df2['reviewText'] = df2['reviewText'].apply(tokenize_text)

# Tokenizing 'summary' column
df2['summary'] = df2['summary'].apply(tokenize_text)

print()

# %%
# printing reviewText 
print("Tokenized Review Text:")
for index, tokens in enumerate(df2['reviewText'].head(), start=1):
    print(f"Row {index}: {tokens}")

# Printing tokenized summary
print("\nTokenized Summary:")
for index, tokens in enumerate(df2['summary'].head(), start=1):
    print(f"Row {index}: {tokens}")
# Out:
# Tokenized Review Text:
# Row 1: ['All', 'the', 'reviews', 'are', 'not', 'for', 'the', 'product', 'listed', '.', 'Amazon', 'needs', 'to', 'straighten', 'this', 'mess', 'out', '.']
# Row 2: ['So', 'far', ',', 'I', 'am', 'not', 'impressed', '.', 'It', 'did', 'arrive', 'quickly', ',', 'but', 'it', 'does', 'not', 'work', 'for', 'us', '.', 'I', 'followed', 'the', 'instructions', 'to', 'a', '``', 'T', "''", 'several', 'times', 'on', 'several', 'devices', 'and', 'it', 'would', 'not', 'connect', '.', 'I', 'started', 'skeptical', 'because', 'there', 'is', 'no', 'product', 'on', 'Amazon', 'that', 'has', '300', 'reviews', 'and', 'every', 'one', 'is', '5', 'stars', '.', 'This', 'is', 'literally', 'the', '2nd', '1-star', 'review', '(', 'and', 'I', 'think', 'the', 'other', 'person', 'was', 'wise', 'for', 'not', 'purchasing', ')', '.', 'I', "'ve", 'grown', 'even', 'more', 'skeptical', 'and', 'plan', 'on', 'returning', 'this', 'product', 'unless', 'someone', 'from', 'Opticover', 'is', 'willing', 'to', 'help', 'out', '.']
# Row 3: ['I', 'looked', 'at', 'purchasing', 'this', 'Router', '.', 'However', ',', 'one', 'has', 'to', 'wonder', 'where', 'these', 'ratings', 'are', 'coming', 'from', 'since', 'some', 'of', 'the', 'reviews', ',', 'along', 'with', 'the', 'questions', 'folks', 'have', 'asked', 'about', 'the', 'product', ',', 'do', 'not', 'seem', 'to', 'have', 'anything', 'to', 'do', 'with', 'this', 'product', '.', "What's-up", 'Amazon', '.']
# Row 4: ['I', 'thought', 'this', 'to', 'be', 'very', 'inexpensive', 'for', 'all', 'that', 'we', 'got', '.', 'Great', 'for', 'the', 'you', 'boys', 'for', 'their', 'computer', 'center', 'in', 'our', 'home', 'school', '.']
# Row 5: ['very', 'good', 'computer', 'the', 'intel', 'Dual', 'Core', 'i3-2120', '3.3GHz', 'CPU', ',', '4GB', 'DDR3', 'RAM', ',', '500GB', 'HDD', 'configuration', 'is', 'good', 'enough', 'for', 'light', 'use', '.', 'The', 'price', 'is', 'amazing']
#
# Tokenized Summary:
# Row 1: ['Does', "n't", 'Make', 'Sense', '.']
# Row 2: ['Does', 'Not', 'Work', '.', 'I', 'Feel', 'I', "'ve", 'Been', '``', 'Had', "''"]
# Row 3: ['I', 'looked', 'at', 'purchasing', 'this', 'Router', '.', 'However', ',', 'one', '...']
# Row 4: ['Great', 'for', 'the', 'you', 'boys', 'for', 'their', 'computer', 'center', 'in', '...']
# Row 5: ['very', 'good', 'computer', 'the', 'intel', 'Dual', 'Core', 'i3-2120', '3']

# %%
df2['reviewText'] = df2['reviewText'].apply(lambda tokens: [token.lower() for token in tokens])

df2['summary'] = df2['summary'].apply(lambda tokens: [token.lower() for token in tokens])

# %%
print("Lowercase Tokens for Review Text:")
for index, tokens in enumerate(df2['reviewText'].head(), start=1):
    print(f"Row {index}: {tokens}")

print("\nLowercase Tokens for Summary:")
for index, tokens in enumerate(df2['summary'].head(), start=1):
    print(f"Row {index}: {tokens}")
# Out:
# Lowercase Tokens for Review Text:
# Row 1: ['all', 'the', 'reviews', 'are', 'not', 'for', 'the', 'product', 'listed', '.', 'amazon', 'needs', 'to', 'straighten', 'this', 'mess', 'out', '.']
# Row 2: ['so', 'far', ',', 'i', 'am', 'not', 'impressed', '.', 'it', 'did', 'arrive', 'quickly', ',', 'but', 'it', 'does', 'not', 'work', 'for', 'us', '.', 'i', 'followed', 'the', 'instructions', 'to', 'a', '``', 't', "''", 'several', 'times', 'on', 'several', 'devices', 'and', 'it', 'would', 'not', 'connect', '.', 'i', 'started', 'skeptical', 'because', 'there', 'is', 'no', 'product', 'on', 'amazon', 'that', 'has', '300', 'reviews', 'and', 'every', 'one', 'is', '5', 'stars', '.', 'this', 'is', 'literally', 'the', '2nd', '1-star', 'review', '(', 'and', 'i', 'think', 'the', 'other', 'person', 'was', 'wise', 'for', 'not', 'purchasing', ')', '.', 'i', "'ve", 'grown', 'even', 'more', 'skeptical', 'and', 'plan', 'on', 'returning', 'this', 'product', 'unless', 'someone', 'from', 'opticover', 'is', 'willing', 'to', 'help', 'out', '.']
# Row 3: ['i', 'looked', 'at', 'purchasing', 'this', 'router', '.', 'however', ',', 'one', 'has', 'to', 'wonder', 'where', 'these', 'ratings', 'are', 'coming', 'from', 'since', 'some', 'of', 'the', 'reviews', ',', 'along', 'with', 'the', 'questions', 'folks', 'have', 'asked', 'about', 'the', 'product', ',', 'do', 'not', 'seem', 'to', 'have', 'anything', 'to', 'do', 'with', 'this', 'product', '.', "what's-up", 'amazon', '.']
# Row 4: ['i', 'thought', 'this', 'to', 'be', 'very', 'inexpensive', 'for', 'all', 'that', 'we', 'got', '.', 'great', 'for', 'the', 'you', 'boys', 'for', 'their', 'computer', 'center', 'in', 'our', 'home', 'school', '.']
# Row 5: ['very', 'good', 'computer', 'the', 'intel', 'dual', 'core', 'i3-2120', '3.3ghz', 'cpu', ',', '4gb', 'ddr3', 'ram', ',', '500gb', 'hdd', 'configuration', 'is', 'good', 'enough', 'for', 'light', 'use', '.', 'the', 'price', 'is', 'amazing']
#
# Lowercase Tokens for Summary:
# Row 1: ['does', "n't", 'make', 'sense', '.']
# Row 2: ['does', 'not', 'work', '.', 'i', 'feel', 'i', "'ve", 'been', '``', 'had', "''"]
# Row 3: ['i', 'looked', 'at', 'purchasing', 'this', 'router', '.', 'however', ',', 'one', '...']
# Row 4: ['great', 'for', 'the', 'you', 'boys', 'for', 'their', 'computer', 'center', 'in', '...']
# Row 5: ['very', 'good', 'computer', 'the', 'intel', 'dual', 'core', 'i3-2120', '3']

# %%
import re

# Function to remove special characters and spaces from tokens
def remove_special_characters(tokens):
    # Define regex pattern to remove spaces and special characters
    pattern = r'[^a-zA-Z0-9]'  # Keeps letters and numbers
    
    # Remove special characters and spaces using regex
    tokens_no_special = [re.sub(pattern, '', token) for token in tokens]
    tokens_no_special = [token for token in tokens_no_special if token]  # Remove empty strings
    return tokens_no_special

# Remove special characters and spaces from 'reviewText' column
df2['reviewText'] = df2['reviewText'].apply(remove_special_characters)

# Remove special characters and spaces from 'summary' column
df2['summary'] = df2['summary'].apply(remove_special_characters)

# %%
# Print tokens with special characters removed for 'reviewText_tokens_clean' column
print("Tokens with Special Characters Removed for Review Text:")
for index, tokens in enumerate(df2['reviewText'].head(), start=1):
    print(f"Row {index}: {tokens}")

# Print tokens with special characters removed for 'summary_tokens_clean' column
print("\nTokens with Special Characters Removed for Summary:")
for index, tokens in enumerate(df2['summary'].head(), start=1):
    print(f"Row {index}: {tokens}")
# Out:
# Tokens with Special Characters Removed for Review Text:
# Row 1: ['all', 'the', 'reviews', 'are', 'not', 'for', 'the', 'product', 'listed', 'amazon', 'needs', 'to', 'straighten', 'this', 'mess', 'out']
# Row 2: ['so', 'far', 'i', 'am', 'not', 'impressed', 'it', 'did', 'arrive', 'quickly', 'but', 'it', 'does', 'not', 'work', 'for', 'us', 'i', 'followed', 'the', 'instructions', 'to', 'a', 't', 'several', 'times', 'on', 'several', 'devices', 'and', 'it', 'would', 'not', 'connect', 'i', 'started', 'skeptical', 'because', 'there', 'is', 'no', 'product', 'on', 'amazon', 'that', 'has', '300', 'reviews', 'and', 'every', 'one', 'is', '5', 'stars', 'this', 'is', 'literally', 'the', '2nd', '1star', 'review', 'and', 'i', 'think', 'the', 'other', 'person', 'was', 'wise', 'for', 'not', 'purchasing', 'i', 've', 'grown', 'even', 'more', 'skeptical', 'and', 'plan', 'on', 'returning', 'this', 'product', 'unless', 'someone', 'from', 'opticover', 'is', 'willing', 'to', 'help', 'out']
# Row 3: ['i', 'looked', 'at', 'purchasing', 'this', 'router', 'however', 'one', 'has', 'to', 'wonder', 'where', 'these', 'ratings', 'are', 'coming', 'from', 'since', 'some', 'of', 'the', 'reviews', 'along', 'with', 'the', 'questions', 'folks', 'have', 'asked', 'about', 'the', 'product', 'do', 'not', 'seem', 'to', 'have', 'anything', 'to', 'do', 'with', 'this', 'product', 'whatsup', 'amazon']
# Row 4: ['i', 'thought', 'this', 'to', 'be', 'very', 'inexpensive', 'for', 'all', 'that', 'we', 'got', 'great', 'for', 'the', 'you', 'boys', 'for', 'their', 'computer', 'center', 'in', 'our', 'home', 'school']
# Row 5: ['very', 'good', 'computer', 'the', 'intel', 'dual', 'core', 'i32120', '33ghz', 'cpu', '4gb', 'ddr3', 'ram', '500gb', 'hdd', 'configuration', 'is', 'good', 'enough', 'for', 'light', 'use', 'the', 'price', 'is', 'amazing']
#
# Tokens with Special Characters Removed for Summary:
# Row 1: ['does', 'nt', 'make', 'sense']
# Row 2: ['does', 'not', 'work', 'i', 'feel', 'i', 've', 'been', 'had']
# Row 3: ['i', 'looked', 'at', 'purchasing', 'this', 'router', 'however', 'one']
# Row 4: ['great', 'for', 'the', 'you', 'boys', 'for', 'their', 'computer', 'center', 'in']
# Row 5: ['very', 'good', 'computer', 'the', 'intel', 'dual', 'core', 'i32120', '3']

# %%
import nltk
from nltk.corpus import stopwords

# Download NLTK stopwords if not downloaded
nltk.download('stopwords')

# Get English stopwords from NLTK
stop_words = set(stopwords.words('english'))

# Function to remove stopwords from tokens
def remove_stopwords(tokens):
    tokens_no_stop = [token for token in tokens if token not in stop_words]
    return tokens_no_stop

# Remove stopwords from 'reviewText_tokens_no_punct' column
df2['reviewText'] = df2['reviewText'].apply(remove_stopwords)

# Remove stopwords from 'summary_tokens_no_punct' column
df2['summary'] = df2['summary'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vinut\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Print tokens without stopwords for 'reviewText_tokens_no_stop' column
print("Tokens without Stopwords for Review Text:")
for index, tokens in enumerate(df2['reviewText'].head(), start=1):
    print(f"Row {index}: {tokens}")

# Print tokens without stopwords for 'summary_tokens_no_stop' column
print("\nTokens without Stopwords for Summary:")
for index, tokens in enumerate(df2['summary'].head(), start=1):
    print(f"Row {index}: {tokens}")
# Out:
# Tokens without Stopwords for Review Text:
# Row 1: ['reviews', 'product', 'listed', 'amazon', 'needs', 'straighten', 'mess']
# Row 2: ['far', 'impressed', 'arrive', 'quickly', 'work', 'us', 'followed', 'instructions', 'several', 'times', 'several', 'devices', 'would', 'connect', 'started', 'skeptical', 'product', 'amazon', '300', 'reviews', 'every', 'one', '5', 'stars', 'literally', '2nd', '1star', 'review', 'think', 'person', 'wise', 'purchasing', 'grown', 'even', 'skeptical', 'plan', 'returning', 'product', 'unless', 'someone', 'opticover', 'willing', 'help']
# Row 3: ['looked', 'purchasing', 'router', 'however', 'one', 'wonder', 'ratings', 'coming', 'since', 'reviews', 'along', 'questions', 'folks', 'asked', 'product', 'seem', 'anything', 'product', 'whatsup', 'amazon']
# Row 4: ['thought', 'inexpensive', 'got', 'great', 'boys', 'computer', 'center', 'home', 'school']
# Row 5: ['good', 'computer', 'intel', 'dual', 'core', 'i32120', '33ghz', 'cpu', '4gb', 'ddr3', 'ram', '500gb', 'hdd', 'configuration', 'good', 'enough', 'light', 'use', 'price', 'amazing']
#
# Tokens without Stopwords for Summary:
# Row 1: ['nt', 'make', 'sense']
# Row 2: ['work', 'feel']
# Row 3: ['looked', 'purchasing', 'router', 'however', 'one']
# Row 4: ['great', 'boys', 'computer', 'center']
# Row 5: ['good', 'computer', 'intel', 'dual', 'core', 'i32120', '3']

# %%
df2
# Out:
#      overall      reviewerID        asin  \
# 0        1.0  A2HL609RR13WNZ  B000EORV8Q
# 1        1.0  A14HDK1OLFYMVM  B000EORV8Q
# 2        1.0  A3P2DW4YDYK88C  B000EORV8Q
# 3        5.0  A2N4Y0OQ8RP88Y  B000EORV8Q
# 4        5.0  A24G9X47GNVI02  B000EORV8Q
# ..       ...             ...         ...
# 227      5.0   AFFTVSSV0D5A1  B000EORV8Q
# 228      5.0  A3TLPNECI4DG3N  B000EORV8Q
# 229      5.0  A1MJWOYNJSZPPJ  B000EORV8Q
# 230      1.0  A2RV54OXBGRD2Z  B000EORV8Q
# 231      5.0  A3PWOYJPO4CT93  B000EORV8Q
#
#                                             reviewText  \
# 0    [reviews, product, listed, amazon, needs, stra...
# 1    [far, impressed, arrive, quickly, work, us, fo...
# 2    [looked, purchasing, router, however, one, won...
# 3    [thought, inexpensive, got, great, boys, compu...
# 4    [good, computer, intel, dual, core, i32120, 33...
# ..                                                 ...
# 227  [satisfied, purchase, wireless, router, setup,...
# 228  [need, network, computers, different, floors, ...
# 229  [ca, nt, go, wrong, device, hub, operates, sol...
# 230  [review, 5, stars, really, wonder, real, nt, s...
# 231  [perfect, device, thing, would, make, better, ...
#
#                                                summary
# 0                                    [nt, make, sense]
# 1                                         [work, feel]
# 2           [looked, purchasing, router, however, one]
# 3                      [great, boys, computer, center]
# 4       [good, computer, intel, dual, core, i32120, 3]
# ..                                                 ...
# 227                  [good, product, easy, setup, use]
# 228                    [easy, set, works, like, dream]
# 229                                 [solid, performer]
# 230  [nt, stay, connected, whole, time, would, reco...
# 231              [perfect, device, thing, would, make]
#
# [232 rows x 5 columns]

# %%
# Function to get sentiment polarity
from textblob import TextBlob
def get_sentiment(text):
    analysis = TextBlob(str(text))
    return analysis.sentiment.polarity
df2['sentiment'] = df2['reviewText'].apply(get_sentiment)
print(df2[['reviewText', 'sentiment']].head(10))
# Out:
#                                           reviewText  sentiment
# 0  [reviews, product, listed, amazon, needs, stra...  -0.175000
# 1  [far, impressed, arrive, quickly, work, us, fo...   0.138333
# 2  [looked, purchasing, router, however, one, won...   0.000000
# 3  [thought, inexpensive, got, great, boys, compu...   0.350000
# 4  [good, computer, intel, dual, core, i32120, 33...   0.480000
# 5  [fantastic, deal, fast, great, screen, solid, ...   0.420000
# 6  [convertible, size, hard, drive, space, like, ...  -0.291667
# 7                                    [awesome, fast]   0.600000
# 8  [covers, screen, barely, sides, falls, bit, sh...   0.286429
# 9                                           [thanks]   0.200000

# %%
# Function to convert sentiment scores to categorical values
def get_sentiment_category(score):
    if score >= 0.3:  
        return 1  # Positive sentiment
    elif score < -0.1:
        return -1  # Negative sentiment
    else:
        return 0  # Neutral sentiment or no strong sentiment
df2['sentiment_category'] = df2['sentiment'].apply(get_sentiment_category)
df2.head(50)
# Out:
#     overall      reviewerID        asin  \
# 0       1.0  A2HL609RR13WNZ  B000EORV8Q
# 1       1.0  A14HDK1OLFYMVM  B000EORV8Q
# 2       1.0  A3P2DW4YDYK88C  B000EORV8Q
# 3       5.0  A2N4Y0OQ8RP88Y  B000EORV8Q
# 4       5.0  A24G9X47GNVI02  B000EORV8Q
# 5       5.0  A1JV5541KYYH9Y  B000EORV8Q
# 6       5.0  A3HM2ZVKF7Z8LJ  B000EORV8Q
# 7       5.0  A147A9US858FV8  B000EORV8Q
# 8       5.0  A1HJTB0MIC4KQN  B000EORV8Q
# 9       5.0   A7NGASCWV27S7  B000EORV8Q
# 10      5.0  A1V68ZGRMUT7YC  B000EORV8Q
# 11      5.0   AOEYPSPIR3HBL  B000EORV8Q
# 12      5.0  A3AKH3YQJ0POOA  B000EORV8Q
# 13      5.0  A3OZW1RD3LLRK8  B000EORV8Q
# 14      5.0  A24KVXQCVQ4XE8  B000EORV8Q
# 15      5.0  A3UZ2RCTUN4S9Z  B000EORV8Q
# 16      5.0  A18S5P9VX4QL18  B000EORV8Q
# 17      5.0  A366GHYFWYLVCI  B000EORV8Q
# 18      5.0   ACP6W0CULQ26N  B000EORV8Q
# 19      5.0   AIT20JDK6ZWZN  B000EORV8Q
# 20      5.0  A1LNWNTJV8OXKC  B000EORV8Q
# 21      5.0  A2RM0Q8VFSH0OW  B000EORV8Q
# 22      5.0  A2QU1RTXCWNAVA  B000EORV8Q
# 23      5.0  A2GG6IJ55UX6YZ  B000EORV8Q
# 24      5.0  A32OJFTLJUUPZI  B000EORV8Q
# 25      5.0   ALXRKQ572JVN4  B000EORV8Q
# 26      5.0   AK3K19MB191ZO  B000EORV8Q
# 27      5.0  A28ZB85V5UMY22  B000EORV8Q
# 28      5.0  A1TZ9MCWA6EHJ1  B000EORV8Q
# 29      5.0  A3V1DM71RMGBFB  B000EORV8Q
# 30      5.0  A1SLOSK3LFHWM1  B000EORV8Q
# 31      5.0  A3D44572MFVIMI  B000EORV8Q
# 32      5.0  A17NJXNQKWSY62  B000EORV8Q
# 33      5.0  A3K082UB8PHLO5  B000EORV8Q
# 34      5.0  A1I7HLVM8OHMCF  B000EORV8Q
# 35      5.0  A20PKGHQ0KQPXH  B000EORV8Q
# 36      5.0  A1YZDWOWFXC094  B000EORV8Q
# 37      5.0   A4EJM72NKO4YM  B000EORV8Q
# 38      5.0  A1JZFGZEZVWQPY  B000EORV8Q
# 39      5.0  A1OJ9V614SM587  B000EORV8Q
# 40      5.0  A2ETPOKJOA57W6  B000EORV8Q
# 41      5.0  A1JZFGZEZVWQPY  B000EORV8Q
# 42      5.0   AI6YOSOWFYF82  B000EORV8Q
# 43      5.0  A31N0XY2UTB25C  B000EORV8Q
# 44      5.0  A3RK4C2I5SPZNO  B000EORV8Q
# 45      5.0  A1E3P6P5I9H215  B000EORV8Q
# 46      5.0  A1OP3DBLTQC5SR  B000EORV8Q
# 47      5.0  A1JZFGZEZVWQPY  B000EORV8Q
# 48      5.0  A3VNNC6YER083I  B000EORV8Q
# 49      5.0  A1CTO812YAY1QP  B000EORV8Q
#
#                                            reviewText  \
# 0   [reviews, product, listed, amazon, needs, stra...
# 1   [far, impressed, arrive, quickly, work, us, fo...
# 2   [looked, purchasing, router, however, one, won...
# 3   [thought, inexpensive, got, great, boys, compu...
# 4   [good, computer, intel, dual, core, i32120, 33...
# 5   [fantastic, deal, fast, great, screen, solid, ...
# 6   [convertible, size, hard, drive, space, like, ...
# 7                                     [awesome, fast]
# 8   [covers, screen, barely, sides, falls, bit, sh...
# 9                                            [thanks]
# 10  [using, month, fast, starts, quickly, screen, ...
# 11  [delivered, time, product, exactly, described,...
# 12                                        [estupendo]
# 13  [took, whole, get, works, well, seems, well, c...
# 14                                [great, value, wap]
# 15        [speedy, little, laptops, 1000, pay, would]
# 16                          [grandson, happy, laptop]
# 17               [great, find, seller, stellar, need]
# 18                                            [great]
# 19  [unit, came, used, fine, condition, seems, wor...
# 20                                        [excellent]
# 21  [great, price, company, also, provides, massiv...
# 22                  [years, works, great, power, sag]
# 23                            [ap, rocks, miss, 3com]
# 24                                 [love, good, deal]
# 25     [shelved, item, found, significant, rf, noise]
# 26  [worked, us, reliably, complaint, functioning,...
# 27                                [good, four, years]
# 28       [bought, son, mac, works, great, hp, laptop]
# 29                              [nice, simple, works]
# 30                             [omg, router, amazing]
# 31                                  [works, expected]
# 32  [nice, rack, deep, enough, network, switches, ...
# 33  [ok, deal, got, 2, 1, i5core, 6gb, 1tb, hard, ...
# 34  [nice, price, like, one, phone, company, wante...
# 35                      [work, perfectly, hackintosh]
# 36             [works, nicely, 10, year, old, laptop]
# 37                                        [excellent]
# 38  [qnap, get, lot, money, inexpensive, plex, sup...
# 39                                    [worked, great]
# 40  [give, 5, star, increase, range, significantly...
# 41  [super, home, business, networks, addition, ei...
# 42                                        [excellent]
# 43  [netgear, prosafe, 8port, gigabit, click, swit...
# 44  [item, came, quickly, exactly, described, grea...
# 45  [perfect, needs, used, cable, extend, amp, ant...
# 46                                            [great]
# 47  [unit, much, faster, powerful, trendnets, acce...
# 48                       [excellent, seller, product]
# 49                                   [everything, ok]
#
#                                               summary  sentiment  \
# 0                                   [nt, make, sense]  -0.175000
# 1                                        [work, feel]   0.138333
# 2          [looked, purchasing, router, however, one]   0.000000
# 3                     [great, boys, computer, center]   0.350000
# 4      [good, computer, intel, dual, core, i32120, 3]   0.480000
# 5                   [excellent, value, high, quality]   0.420000
# 6                                       [convertible]  -0.291667
# 7                                       [five, stars]   0.600000
# 8                        [may, look, like, protector]   0.286429
# 9                                       [five, stars]   0.200000
# 10                                     [using, month]   0.177778
# 11                                      [five, stars]   0.250000
# 12                                      [five, stars]   0.000000
# 13                    [took, whole, get, works, well]   0.200000
# 14                                      [five, stars]   0.800000
# 15                    [speedy, little, work, laptops]  -0.187500
# 16                                      [five, stars]   0.800000
# 17                     [great, find, seller, stellar]   0.525000
# 18                                      [five, stars]   0.800000
# 19            [fine, condition, seems, working, well]   0.408333
# 20                                        [excellent]   1.000000
# 21                                      [five, stars]   0.400000
# 22                                             [love]   0.800000
# 23                                       [miss, 3com]   0.000000
# 24                                      [five, stars]   0.600000
# 25                 [product, works, needs, shielding]   0.375000
# 26  [switch, offers, lightweight, reduced, dimensi...   0.077778
# 27                                      [five, stars]   0.700000
# 28                                      [five, stars]   0.800000
# 29                                      [five, stars]   0.300000
# 30                                          [amazing]   0.600000
# 31                                      [five, stars]  -0.100000
# 32                                 [love, nice, rack]   0.258333
# 33                                    [ok, deal, got]  -0.084817
# 34                                      [five, stars]   0.508333
# 35                                      [five, stars]   1.000000
# 36                                      [works, good]   0.350000
# 37                                        [excellent]   1.000000
# 38                                     [ts, 251, nas]  -0.114405
# 39                                        [nice, buy]   0.800000
# 40                          [give, 5, star, increase]   0.150000
# 41                  [super, home, business, networks]   0.314815
# 42                                      [five, stars]   1.000000
# 43  [outstanding, design, feature, rich, easily, m...   0.238675
# 44               [great, price, way, cheaper, seller]   0.339583
# 45                             [great, jumper, cable]   1.000000
# 46                                      [five, stars]   0.800000
# 47                                 [pleased, results]   0.033444
# 48                               [excellent, product]   1.000000
# 49                                      [five, stars]   0.500000
#
#     sentiment_category
# 0                   -1
# 1                    0
# 2                    0
# 3                    1
# 4                    1
# 5                    1
# 6                   -1
# 7                    1
# 8                    0
# 9                    0
# 10                   0
# 11                   0
# 12                   0
# 13                   0
# 14                   1
# 15                  -1
# 16                   1
# 17                   1
# 18                   1
# 19                   1
# 20                   1
# 21                   1
# 22                   1
# 23                   0
# 24                   1
# 25                   1
# 26                   0
# 27                   1
# 28                   1
# 29                   1
# 30                   1
# 31                   0
# 32                   0
# 33                   0
# 34                   1
# 35                   1
# 36                   1
# 37                   1
# 38                  -1
# 39                   1
# 40                   0
# 41                   1
# 42                   1
# 43                   0
# 44                   1
# 45                   1
# 46                   1
# 47                   0
# 48                   1
# 49                   1

# %%
df2['sentiment_category'].value_counts()
# Out:
# sentiment_category
#  0    114
#  1    108
# -1     10
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
sentiment_categories = [114, 108, 10]
categories = ['Positive', 'Neutral', 'Negative']

#bar plot
plt.figure(figsize=(8, 6))
plt.bar(categories, sentiment_categories, color=['green', 'blue', 'red'])
plt.xlabel('Sentiment Category')
plt.ylabel('Frequency')
plt.title('Distribution of Sentiment Categories')
plt.show()

# %%
from nltk import pos_tag, word_tokenize
from collections import Counter
from wordcloud import WordCloud

positive_reviews = df2[df2['sentiment_category'] == 1]['reviewText']
feature_words = [word for review in positive_reviews for word in review]
feature_word_freq = Counter(feature_words)
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(feature_word_freq)
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Frequent Features in Positive Reviews')
plt.show()

top_features = feature_word_freq.most_common(10)  # Top 10 features
feature_names, frequencies = zip(*top_features)

plt.figure(figsize=(10, 6))
plt.barh(feature_names, frequencies, color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('Feature')
plt.title('Top Features in Positive Reviews')
plt.gca().invert_yaxis()
plt.show()

# %%
def get_sentiment(text):
    analysis = TextBlob(str(text))
    return analysis.sentiment.polarity
df2['sentiment2'] = df2['summary'].apply(get_sentiment)
print(df2[['summary', 'sentiment2']].head(10))
# Out:
#                                           summary  sentiment2
# 0                               [nt, make, sense]        0.00
# 1                                    [work, feel]        0.00
# 2      [looked, purchasing, router, however, one]        0.00
# 3                 [great, boys, computer, center]        0.35
# 4  [good, computer, intel, dual, core, i32120, 3]        0.70
# 5               [excellent, value, high, quality]        0.58
# 6                                   [convertible]        0.00
# 7                                   [five, stars]        0.00
# 8                    [may, look, like, protector]        0.00
# 9                                   [five, stars]        0.00

# %%
def get_sentiment_category(score):
    if score > 0.5: 
        return 1  # Positive sentiment
    elif score < -0.1:
        return -1  # Negative sentiment
    else:
        return 0  # Neutral sentiment or no strong sentiment

df2['sentiment2_category'] = df2['sentiment2'].apply(get_sentiment_category)
print(df2[['summary', 'sentiment2_category']].head(10))
# Out:
#                                           summary  sentiment2_category
# 0                               [nt, make, sense]                    0
# 1                                    [work, feel]                    0
# 2      [looked, purchasing, router, however, one]                    0
# 3                 [great, boys, computer, center]                    0
# 4  [good, computer, intel, dual, core, i32120, 3]                    1
# 5               [excellent, value, high, quality]                    1
# 6                                   [convertible]                    0
# 7                                   [five, stars]                    0
# 8                    [may, look, like, protector]                    0
# 9                                   [five, stars]                    0

# %%
from nltk import pos_tag, word_tokenize
from collections import Counter
from wordcloud import WordCloud
positive_reviews = df2[df2['sentiment2_category'] == 1]['summary']
feature_words = [word for review in positive_reviews for word in review]
feature_word_freq = Counter(feature_words)
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(feature_word_freq)
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Frequent Features in Positive Reviews')
plt.show()

top_features = feature_word_freq.most_common(10)  # Top 10 features
feature_names, frequencies = zip(*top_features)

plt.figure(figsize=(10, 6))
plt.barh(feature_names, frequencies, color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('Feature')
plt.title('Top Features in Positive Reviews')
plt.gca().invert_yaxis()
plt.show()

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\vinut\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#Aspect based sentiment analysis
from nltk import pos_tag
tagged_feature = pos_tag(feature_words)
aspect_keyword = [word for word, pos in tagged_feature if pos in ['NN', 'NNS', 'JJ']]
print(aspect_keyword)
# Out:
# ['good', 'computer', 'dual', 'core', 'i32120', 'excellent', 'value', 'high', 'quality', 'great', 'seller', 'stellar', 'excellent', 'love', 'nice', 'rack', 'good', 'excellent', 'nice', 'buy', 'great', 'price', 'way', 'seller', 'great', 'jumper', 'cable', 'excellent', 'product', 'dial', 'modem', 'upgrade', 'works', 'great', 'good', 'deal', 'great', 'fits', 'lowprofile', 'pc', 'good', 'item', 'good', 'deal', 'flawless', 'easy', 'setup', 'perfect', 'performance', 'switch', 'good', 'product', 'great', 'price', 'great', 'gadget', 'wifi', 'avoid', 'wifi', 'case', 'good', 'investment', 'nice', 'outstanding', 'wireless', 'good', 'price', 'perfect', 'worked', 'great', 'right', 'box', 'perfect', 'great', 'results', 'great', 'excellent', 'good', 'product', 'excellent', 'value', 'great', 'upgrade', 'great', 'array', 'price', 'easy', 'plug', 'great', 'performace', 'great', 'great', 'product', 'great', 'amazing', 'product', 'great', 'product', 'perfect', 'perfect', 'combination', 'qnap', 'nas', 'good', 'product', 'great', 'item', 'great', 'price', 'great', 'product', 'right', 'great', 'good', 'home', 'network', 'high', 'gain', 'great', 'router', 'great', 'security', 'solution', 'robotics', 'port', 'gigabit', 'excellent', 'engenius', 'products', 'great', 'switch', 'ports', 'great', 'product', 'amazing', 'machine', 'price', 'great', 'fantastic', 'price', 'great', 'product', 'modem', 'works', 'switch', 'excellent', 'device', 'usb', 'hub', 'great', 'switch', 'great', 'features', 'low', 'cost', 'speed', 'works', 'great', 'great', 'modem', 'great', 'home', 'switch', 'vlan', 'support', 'come', 'great', 'product', 'great', 'excellent', 'switch', 'excellent', 'combo', 'card', 'great', 'excellent', 'helpful', 'great', 'router', 'good', 'product', 'good', 'price', 'great', 'usb', 'card', 'good', 'product', 'easy', 'setup', 'use', 'perfect', 'device', 'thing']

# %%
df_aspect = pd.read_csv('C:\\Users\\vinut\\Desktop\\DataMining Project\\B000EORV8Q_data.csv')

df_aspect.head(5)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  style  \
# 0      1.0     False  05 15, 2018  A2HL609RR13WNZ  B000EORV8Q    NaN
# 1      1.0      True  05 14, 2018  A14HDK1OLFYMVM  B000EORV8Q    NaN
# 2      1.0     False  05 13, 2018  A3P2DW4YDYK88C  B000EORV8Q    NaN
# 3      5.0      True   04 9, 2018  A2N4Y0OQ8RP88Y  B000EORV8Q    NaN
# 4      5.0      True  03 28, 2018  A24G9X47GNVI02  B000EORV8Q    NaN
#
#              reviewerName                                         reviewText  \
# 0  George Leroy Tirebiter  All the reviews are not for the product listed...
# 1                      AL  So far, I am not impressed. It did arrive quic...
# 2                W. Racca  I looked at purchasing this Router.  However, ...
# 3              Pat Senter  I thought this to be very inexpensive for all ...
# 4                  Freddy  very good computer the intel Dual Core i3-2120...
#
#                                              summary  unixReviewTime  vote  \
# 0                                Doesn't Make Sense.      1526342400   NaN
# 1              Does Not Work. I Feel I've Been "Had"      1526256000   NaN
# 2  I looked at purchasing this Router. However, o...      1526169600   NaN
# 3  Great for the you boys for their computer cent...      1523232000   NaN
# 4   very good computer the intel Dual Core i3-2120 3      1522195200   NaN
#
#    image
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
def extract_aspects(text):
    doc = nlp(text)
    aspects = []
    for token in doc:
        if token.pos_ == "NOUN":    #extracts noun
            aspects.append(token.text)
    return aspects


review_text = "All the reviews are not for the product listed. Amazon needs to straighten this mess out"
aspects = extract_aspects(review_text)
print("Aspects:",aspects)
# Out:
# Aspects: ['reviews', 'product', 'mess']

# %%
df_review = df_aspect['reviewText']

def extract_aspects(text):
    doc = nlp(text)
    aspects = [token.text for token in doc if token.pos_ == "NOUN"]
    return aspects

# applying the extract_aspects function to the 'reviewText' column
df_aspects = df_review.apply(extract_aspects)
df_review = pd.DataFrame(df_review)
df_review['aspects'] = df_aspects
df_review = df_review.rename(columns={'reviewText': 'reviews'})
print(df_review)
# Out:
#                                                reviews  \
# 0    All the reviews are not for the product listed...
# 1    So far, I am not impressed. It did arrive quic...
# 2    I looked at purchasing this Router.  However, ...
# 3    I thought this to be very inexpensive for all ...
# 4    very good computer the intel Dual Core i3-2120...
# ..                                                 ...
# 227  I am very satisfied with the purchase of this ...
# 228  Need to network computers on different floors?...
# 229  You can't go wrong with this device.  It's the...
# 230  The review that has 5 stars\nI really wonder t...
# 231  perfect device. the only thing that would Make...
#
#                                                aspects
# 0                             [reviews, product, mess]
# 1    [instructions, times, devices, product, review...
# 2    [Router, ratings, reviews, questions, folks, p...
# 3               [boys, computer, center, home, school]
# 4       [computer, i3, HDD, configuration, use, price]
# ..                                                 ...
# 227  [purchase, router, setup, minutes, setup, wiza...
# 228  [computers, floors, product, bridge, interface...
# 229                               [device, hub, power]
# 230                     [review, stars, time, product]
# 231                            [device, thing, people]
#
# [232 rows x 2 columns]

# %%
from collections import Counter
all_aspects = [aspect for sublist in df_review['aspects'] for aspect in sublist]
aspect_counts = Counter(all_aspects)
top_aspects = aspect_counts.most_common(5)

# Print the top aspects and their counts
print("Top Aspects:")
for aspect, count in top_aspects:
    print(f"{aspect}: {count} mentions")
# Out:
# Top Aspects:
# product: 65 mentions
# port: 65 mentions
# switch: 56 mentions
# router: 53 mentions
# power: 47 mentions

# %%
aspects, counts = zip(*top_aspects)

# Plotting the graph
plt.figure(figsize=(10, 6))
plt.bar(aspects, counts, color='skyblue')
plt.xlabel('Aspects')
plt.ylabel('Frequency')
plt.title('Top Aspects or Features')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
aspects, counts = zip(*top_aspects)

#pie chart
plt.figure(figsize=(8, 8))
plt.pie(counts, labels=aspects, autopct='%1.1f%%', startangle=140)
plt.title('Top Aspects Distribution')
plt.axis('equal')  
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings("ignore")

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_review['reviews'], df2['sentiment_category'], test_size=0.4, random_state=42)
model = make_pipeline(TfidfVectorizer(), SVC(kernel='linear', random_state=42))
#model = make_pipeline(TfidfVectorizer(), RandomForestClassifier(n_estimators=100, random_state=42))
model.fit(X_train, y_train)   #Fit the model
predictions = model.predict(X_test) # Make predictions on the test set

#find accuracy
accuracy = accuracy_score(y_test, predictions)
print("Test Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, predictions))

# For new reviews,predict:
new_reviews = [
    "Very disappointed with the performance. Would not recommend.",
    "Amazing product",
    "very disappointed",
    "Bad product",
    "Good Product, very pleased",
    "bad product","Excellent Product"
]
new_predictions = model.predict(new_reviews)
print("\nPredicted Sentiments for New Reviews:", new_predictions)
# Out:
# Test Accuracy: 0.6236559139784946
#
# Classification Report:
#                precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         4
#            0       0.57      0.88      0.69        43
#            1       0.77      0.43      0.56        46
#
#     accuracy                           0.62        93
#    macro avg       0.45      0.44      0.42        93
# weighted avg       0.64      0.62      0.59        93
#
#
# Predicted Sentiments for New Reviews: [0 1 0 0 1 0 1]

# %%
sentiment_mapping = {
    0: 'Negative',
    1: 'Positive'
}
predicted_sentiments = [sentiment_mapping[label] for label in new_predictions]
colors = ['red' if pred == 'Negative' else 'green' for pred in predicted_sentiments]

# Plotting sentiment predictions for new reviews
plt.figure(figsize=(10, 6))
plt.barh(range(len(new_reviews)), [1 if pred == 'Positive' else -1 for pred in predicted_sentiments], color=colors)
plt.yticks(range(len(new_reviews)), new_reviews)
plt.xlabel('Sentiment')
plt.title('Sentiment Predictions for New Reviews')
plt.gca().invert_yaxis()  # Invert y-axis to display the most recent review at the top
plt.show()

# %%
# top aspects and associated sentiment words with their synonyms
aspect_sentiments = {
    'product': ['excellent', 'good', 'great', 'bad', 'poor', 'disappointing'],
    'router': ['fast', 'reliable', 'slow', 'unreliable'],
    'switch': ['efficient', 'effective', 'inefficient', 'ineffective'],
    'port': ['compatible', 'incompatible', 'functional', 'non-functional'],
    'device': ['sophisticated', 'basic', 'advanced', 'outdated']
}

# rule-based sentiment analysis approach:
def rule_based_sentiment_analysis(review):
    sentiment_scores = {}
    for aspect, sentiment_words in aspect_sentiments.items():
        aspect_sentiment = 'neutral'
        for word in sentiment_words:
            if isinstance(review, str) and isinstance(word, str) and word in review.lower():
                aspect_sentiment = 'positive'
                break
        sentiment_scores[aspect] = aspect_sentiment
    
    return sentiment_scores
top_aspects = ['product', 'port', 'switch', 'router', 'power']
for aspect in top_aspects:
    reviews_with_aspect = df_review[df_review['aspects'].apply(lambda x: aspect in x)]['reviews']
    aspect_sentiments = reviews_with_aspect.apply(rule_based_sentiment_analysis)
    for idx, sentiments in aspect_sentiments.items():
        print(f"Review: {idx}")
        print("Sentiments:", sentiments)
    print()
# Out:
# Review: 0
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 1
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 2
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 11
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 43
# Sentiments: {'product': 'positive', 'router': 'positive', 'switch': 'neutral', 'port': 'neutral', 'device': 'positive'}
# Review: 54
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 56
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 59
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 65
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 67
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'positive'}
# Review: 69
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 71
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 76
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 78
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 92
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 95
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 97
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 101
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'positive', 'device': 'neutral'}
# Review: 103
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 114
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 116
# Sentiments: {'product': 'neutral', 'router': 'positive', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 118
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 125
# Sentiments: {'product': 'positive', 'router': 'positive', 'switch': 'positive', 'port': 'neutral', 'device': 'neutral'}
# Review: 126
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 128
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 129
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 132
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 138
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 147
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'positive'}
# Review: 149
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 150
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 156
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'positive'}
# Review: 162
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 165
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 184
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 187
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 191
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 195
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 198
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 204
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 207
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'positive', 'device': 'neutral'}
# Review: 209
# Sentiments: {'product': 'positive', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 227
# Sentiments: {'product': 'neutral', 'router': 'positive', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 228
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
# Review: 230
# Sentiments: {'product': 'neutral', 'router': 'neutral', 'switch': 'neutral', 'port': 'neutral', 'device': 'neutral'}
#
# Review: 38
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 41
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 43
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 66
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 77
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 93
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 106
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 107
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 111
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 118
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 121
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 141
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 143
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 150
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 151
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 161
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 164
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 167
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 170
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 175
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 176
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 177
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 201
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 216
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 218
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 221
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 222
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 223
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
# Review: 224
# Sentiments: {0: 'positive', 1: 'positive', 2: 'positive', 11: 'positive', 43: 'positive', 54: 'positive', 56: 'positive', 59: 'positive', 65: 'positive', 67: 'positive', 69: 'positive', 71: 'positive', 76: 'positive', 78: 'positive', 92: 'positive', 95: 'positive', 97: 'positive', 101: 'positive', 103: 'positive', 114: 'positive', 116: 'positive', 118: 'positive', 125: 'positive', 126: 'positive', 128: 'positive', 129: 'positive', 132: 'positive', 138: 'positive', 147: 'positive', 149: 'positive', 150: 'positive', 156: 'positive', 162: 'positive', 165: 'positive', 184: 'positive', 187: 'positive', 191: 'positive', 195: 'positive', 198: 'positive', 204: 'positive', 207: 'positive', 209: 'positive', 227: 'positive', 228: 'positive', 230: 'positive'}
#
# Review: 26
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 41
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 43
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 44
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 69
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 70
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 77
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 108
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 109
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 115
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 118
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 151
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 159
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 161
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 168
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 170
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 173
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 175
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 180
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 183
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 189
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 191
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 198
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 221
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 223
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
# Review: 228
# Sentiments: {38: 'neutral', 41: 'neutral', 43: 'neutral', 66: 'neutral', 77: 'neutral', 93: 'neutral', 106: 'neutral', 107: 'neutral', 111: 'neutral', 118: 'neutral', 121: 'neutral', 141: 'neutral', 143: 'neutral', 150: 'neutral', 151: 'neutral', 161: 'neutral', 164: 'neutral', 167: 'neutral', 170: 'neutral', 175: 'neutral', 176: 'neutral', 177: 'neutral', 201: 'neutral', 216: 'neutral', 218: 'neutral', 221: 'neutral', 222: 'neutral', 223: 'neutral', 224: 'neutral'}
#
# Review: 30
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 40
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 88
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 117
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 121
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 122
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 132
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 133
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 137
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 140
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 145
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 148
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 150
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 164
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 165
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 169
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 178
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 201
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 206
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 208
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 213
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 214
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 216
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 219
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 221
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 223
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
# Review: 227
# Sentiments: {26: 'neutral', 41: 'neutral', 43: 'neutral', 44: 'neutral', 69: 'neutral', 70: 'neutral', 77: 'neutral', 108: 'neutral', 109: 'neutral', 115: 'neutral', 118: 'neutral', 151: 'neutral', 159: 'neutral', 161: 'neutral', 168: 'neutral', 170: 'neutral', 173: 'neutral', 175: 'neutral', 180: 'neutral', 183: 'neutral', 189: 'neutral', 191: 'neutral', 198: 'neutral', 221: 'neutral', 223: 'neutral', 228: 'neutral'}
#
# Review: 22
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 41
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 43
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 47
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 68
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 91
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 106
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 108
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 121
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 123
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 124
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 126
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 137
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 138
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 152
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 157
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 167
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 170
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 188
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 194
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 207
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 218
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 228
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
# Review: 229
# Sentiments: {30: 'neutral', 40: 'neutral', 88: 'neutral', 117: 'neutral', 121: 'neutral', 122: 'neutral', 132: 'neutral', 133: 'neutral', 137: 'neutral', 140: 'neutral', 145: 'neutral', 148: 'neutral', 150: 'neutral', 164: 'neutral', 165: 'neutral', 169: 'neutral', 178: 'neutral', 201: 'neutral', 206: 'neutral', 208: 'neutral', 213: 'neutral', 214: 'neutral', 216: 'neutral', 219: 'neutral', 221: 'neutral', 223: 'neutral', 227: 'neutral'}
